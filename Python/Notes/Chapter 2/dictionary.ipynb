# %% [raw]
# #dictionary -->
# It is key,value paired object
# Here keys are unique/no duplicates
# here values can be duplicate
# keys are primitive not object type
# value could be anything
# key and value pairs are called items
# Item having one key and one value
# * dictionary will not have index numbers

# %%
#dictionary syntax
#dict_name = {key1:value1,key2:value2}

# %%
D1 = {'a':'apple','b':'banana','c':'cherry','d':'dragonfruit'}
D2 = {1:100,2:200,3:300,4:400}
days = {1:'sun',2:'mon',3:'tue',4:'wed',5:'thu',6:'fri',7:'sat'}
students = {101:['raju','python',5000],102:['ravi','react',4500]}
student_info = {
    101:{'name':'raju','course':'python','fee':5000},
    102:{'name':'ravi','course':'react','fee':4500}
}

# %%
print(D1)
print(D2)
print(days)
print(students)
print(student_info)
# Out:
# {'a': 'apple', 'b': 'banana', 'c': 'cherry', 'd': 'dragonfruit'}
# {1: 100, 2: 200, 3: 300, 4: 400}
# {1: 'sun', 2: 'mon', 3: 'tue', 4: 'wed', 5: 'thu', 6: 'fri', 7: 'sat'}
# {101: ['raju', 'python', 5000], 102: ['ravi', 'react', 4500]}
# {101: {'name': 'raju', 'course': 'python', 'fee': 5000}, 102: {'name': 'ravi', 'course': 'react', 'fee': 4500}}

# %%
D3 = {[1,2,3]:"sids"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 D3 = {[1,2,3]:"sids"}
#
# TypeError: unhashable type: 'list'

# %%
D4 = {hash(1):"Python"}

# %%
D4
# Out:
# {1: 'Python'}

# %%
pow(-4,1/2)
# Out:
# (1.2246467991473532e-16+2j)

# %%
D5 = {pow(-4,1/2):"React"}

# %%
D5
# Out:
# {(1.2246467991473532e-16+2j): 'React'}

# %%
b'a'[0]
# Out:
# 97

# %%
D6 = {b'a'[0]:'welcome'}

# %%
D6
# Out:
# {97: 'welcome'}

# %%
print(D1)
print(D2)
print(days)
# Out:
# {'a': 'apple', 'b': 'banana', 'c': 'cherry', 'd': 'dragonfruit'}
# {1: 100, 2: 200, 3: 300, 4: 400}
# {1: 'sun', 2: 'mon', 3: 'tue', 4: 'wed', 5: 'thu', 6: 'fri', 7: 'sat'}

# %%
#using key we can get value
days[1]
# Out:
# 'sun'

# %%
students
# Out:
# {101: ['raju', 'python', 5000], 102: ['ravi', 'react', 4500]}

# %%
students[101]
# Out:
# ['raju', 'python', 5000]

# %%
students[101][0]
# Out:
# 'raju'

# %%
students[101][1]
# Out:
# 'python'

# %%
students[101][2]
# Out:
# 5000

# %%
student_info
# Out:
# {101: {'name': 'raju', 'course': 'python', 'fee': 5000},
#  102: {'name': 'ravi', 'course': 'react', 'fee': 4500}}

# %%
student_info[101]
# Out:
# {'name': 'raju', 'course': 'python', 'fee': 5000}

# %%
student_info[101]['name']
# Out:
# 'raju'

# %%
student_info[102]['name']
# Out:
# 'ravi'

# %%
a='apple'
b='banana'
c='cherry'

# %%
fruits = {101:a,102:b,103:c}

# %%
fruits
# Out:
# {101: 'apple', 102: 'banana', 103: 'cherry'}

# %%
#empty dictionary

# %%
D1 = {}

# %%
type(D1)
# Out:
# dict

# %%
type(dict)
# Out:
# type

# %%
#create dictionary with dict class

# %%
D1 = dict()

# %%
D1
# Out:
# {}

# %%
fruits = {'a':'apple','b':'banana','c':'cherry','d':'dragonfruit'}

# %%
fruits
# Out:
# {'a': 'apple', 'b': 'banana', 'c': 'cherry', 'd': 'dragonfruit'}

# %%
fruits['a']
# Out:
# 'apple'

# %%
#changing value with help of key
#if key is exited it update value
#if key is not existed it will add new key and value

# %%
D1 = {1:100,2:200,3:300}

# %%
D1[1]=130

# %%
D1
# Out:
# {1: 130, 2: 200, 3: 300}

# %%
D1[4] = 400

# %%
D1
# Out:
# {1: 130, 2: 200, 3: 300, 4: 400}

# %%
#reading dictionary with for loop

# %%
fruits
# Out:
# {'a': 'apple', 'b': 'banana', 'c': 'cherry', 'd': 'dragonfruit'}

# %%
for key in fruits:
    print(key,end="  ")
# Out:
# a  b  c  d

# %%
for key in fruits:
    print(fruits[key],end="  ")
# Out:
# apple  banana  cherry  dragonfruit

# %%
#dictionary methods

# %%
pprint
# Out:
# Pretty printing has been turned OFF

# %%
dir(dict)
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values'

# %%
#clear

# %%
D1 = {1:100,2:200,3:300}

# %%
print(D1)
D1.clear()
print(D1)
# Out:
# {1: 100, 2: 200, 3: 300}
# {}

# %%
#copy

# %%
D1 = {1:100,2:200,3:300}

# %%
D2 = D1.copy()
print(D1)
print(D2)
# Out:
# {1: 100, 2: 200, 3: 300}
# {1: 100, 2: 200, 3: 300}

# %%
print(id(D1))
print(id(D2))
# Out:
# 2839839663680
# 2839840018496

# %%
#'fromkeys'

# %%
sids = [101,102,103,104,105]

# %%
D1 = dict.fromkeys(sids)
print(D1)
# Out:
# {101: None, 102: None, 103: None, 104: None, 105: None}

# %%
D2 = dict.fromkeys(sids,'No Value')
print(D2)
# Out:
# {101: 'No Value', 102: 'No Value', 103: 'No Value', 104: 'No Value', 105: 'No Value'}

# %%
D11 = {1:100,2:200,3:300}

# %%
D3 = dict.fromkeys(D11,0)
print(D3)
# Out:
# {1: 0, 2: 0, 3: 0}

# %%
D3[1]=1*100+2

# %%
D3
# Out:
# {1: 102, 2: 0, 3: 0}

# %%
D11 = {1:100,2:200,3:300,4:400}

# %%
D4 = dict.fromkeys(D11,0)
print(D4)
# Out:
# {1: 0, 2: 0, 3: 0, 4: 0}

# %%
for i in D4:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in D4:
    D4[i]=i*100+2

# %%
D4
# Out:
# {1: 102, 2: 202, 3: 302, 4: 402}

# %%
#

# %%
students = ['raju','ravi','kumar','hari','giri']

# %%
studentInfo = dict.fromkeys(students)

# %%
studentInfo
# Out:
# {'raju': None, 'ravi': None, 'kumar': None, 'hari': None, 'giri': None}

# %%
for i in studentInfo:
    print(i,end="  ")
# Out:
# raju  ravi  kumar  hari  giri

# %%
import itertools

# %%
#module means .py file that contains classes and functions
type(itertools)
# Out:
# <class 'module'>

# %%
from itertools import count

# %%
#count is a class
type(count)
# Out:
# <class 'type'>

# %%
sid = count(5001)

# %%
next(sid)
# Out:
# 5008

# %%
studentInfo
# Out:
# {'raju': None, 'ravi': None, 'kumar': None, 'hari': None, 'giri': None}

# %%
sid = count(7001)

# %%
for name in studentInfo:
    studentInfo[name]=next(sid)

# %%
studentInfo
# Out:
# {'raju': 7001, 'ravi': 7002, 'kumar': 7003, 'hari': 7004, 'giri': 7005}

# %%
#get method

# %%
fruits = {'a': 'apple', 'b': 'banana', 'c': 'cherry', 'd': 'dragonfruit'}

# %%
fruits
# Out:
# {'a': 'apple', 'b': 'banana', 'c': 'cherry', 'd': 'dragonfruit'}

# %%
print(fruits.get('a'))
print(fruits.get('e'))
# Out:
# apple
# None

# %%
fruits['a']
# Out:
# 'apple'

# %%
fruits['e']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 fruits['e']
#
# KeyError: 'e'

# %%
#Items

# %%
fruits
# Out:
# {'a': 'apple', 'b': 'banana', 'c': 'cherry', 'd': 'dragonfruit'}

# %%
fruits.items()
# Out:
# dict_items([('a', 'apple'), ('b', 'banana'), ('c', 'cherry'), ('d', 'dragonfruit')])

# %%
dictItems = fruits.items()

# %%
dictItems
# Out:
# dict_items([('a', 'apple'), ('b', 'banana'), ('c', 'cherry'), ('d', 'dragonfruit')])

# %%
dictItems[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 dictItems[0]
#
# TypeError: 'dict_items' object is not subscriptable

# %%
dictItems[:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 dictItems[:]
#
# TypeError: 'dict_items' object is not subscriptable

# %%
for i in dictItems:
    print(i)
# Out:
# ('a', 'apple')
# ('b', 'banana')
# ('c', 'cherry')
# ('d', 'dragonfruit')

# %%
for i in dictItems:
    print(i[0])
# Out:
# a
# b
# c
# d

# %%
for i in dictItems:
    print(i[1])
# Out:
# apple
# banana
# cherry
# dragonfruit

# %%
for i in dictItems:
    print(i[0],i[1])
# Out:
# a apple
# b banana
# c cherry
# d dragonfruit

# %%
dir(dictItems)
# Out:
# ['__and__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'isdisjoint', 'mapping']

# %%
#values

# %%
fruits.values()
# Out:
# dict_values(['apple', 'banana', 'cherry', 'dragonfruit'])

# %%
dictValues = fruits.values()

# %%
dictValues
# Out:
# dict_values(['apple', 'banana', 'cherry', 'dragonfruit'])

# %%
dictValues[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 dictValues[0]
#
# TypeError: 'dict_values' object is not subscriptable

# %%
dictValues[:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 dictValues[:]
#
# TypeError: 'dict_values' object is not subscriptable

# %%
for i in dictValues:
    print(i)
# Out:
# apple
# banana
# cherry
# dragonfruit

# %%
#keys

# %%
fruits.keys()
# Out:
# dict_keys(['a', 'b', 'c', 'd'])

# %%
dictKeys = fruits.keys()

# %%
dictKeys[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 dictKeys[0]
#
# TypeError: 'dict_keys' object is not subscriptable

# %%
dictKeys[:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 dictKeys[:]
#
# TypeError: 'dict_keys' object is not subscriptable

# %%
for i in dictKeys:
    print(i)
# Out:
# a
# b
# c
# d

# %%
for i in fruits:
    print(i)
# Out:
# a
# b
# c
# d

# %%
# 'pop',

# %%
fruits
# Out:
# {'a': 'apple', 'b': 'banana', 'c': 'cherry', 'd': 'dragonfruit'}

# %%
fruits.pop('b')
# Out:
# 'banana'

# %%
fruits
# Out:
# {'a': 'apple', 'c': 'cherry', 'd': 'dragonfruit'}

# %%
#'popitem',

# %%
fruits
# Out:
# {'a': 'apple', 'c': 'cherry', 'd': 'dragonfruit'}

# %%
fruits.popitem()
# Out:
# ('d', 'dragonfruit')

# %%
fruits
# Out:
# {'a': 'apple', 'c': 'cherry'}

# %%
fruits.popitem()
# Out:
# ('c', 'cherry')

# %%
fruits
# Out:
# {'a': 'apple'}

# %%
#'setdefault',

# %%
D1 = {1:100,2:200,3:300}

# %%
D1[2]=220

# %%
D1
# Out:
# {1: 100, 2: 220, 3: 300}

# %%
D1[4]=400

# %%
D1
# Out:
# {1: 100, 2: 220, 3: 300, 4: 400}

# %%
D1 = {1:100,2:200,3:300}

# %%
D1
# Out:
# {1: 100, 2: 200, 3: 300}

# %%
D1.setdefault(2,250)
# Out:
# 200

# %%
D1
# Out:
# {1: 100, 2: 200, 3: 300}

# %%
D1.setdefault(4,450)
# Out:
# 450

# %%
D1
# Out:
# {1: 100, 2: 200, 3: 300, 4: 450}

# %%
#'update'

# %%
D1 = {1:100,2:200,3:300,4:400}

# %%
D1
# Out:
# {1: 100, 2: 200, 3: 300, 4: 400}
