# %%
L1 = [10,20,30,40,50]

# %%
L2 = L1.copy()

# %%
print(L1)
print(L2)
# Out:
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]

# %%
print(id(L1))
print(id(L2))
# Out:
# 1367396100224
# 1367396099456

# %%
L1[0] = 100

# %%
L1
# Out:
# [100, 20, 30, 40, 50]

# %%
L2
# Out:
# [10, 20, 30, 40, 50]

# %%
L1 = [11,22,33,44,55]

# %%
L1
# Out:
# [11, 22, 33, 44, 55]

# %%
#softcopy
L2 = L1

# %%
print(L1)
print(L2)
# Out:
# [11, 22, 33, 44, 55]
# [11, 22, 33, 44, 55]

# %%
L1[0] = 100

# %%
print(L1)
print(L2)
# Out:
# [100, 22, 33, 44, 55]
# [100, 22, 33, 44, 55]

# %%
print(id(L1))
print(id(L2))
# Out:
# 1367396068992
# 1367396068992
