# %% [raw]
# #what is list?
# * List is a built in class to store more than value
# * it can store any data type values
# * it maintains duplicates also
# * list will have positive/negative indexes

# %%
L1 = [10,20,30,40,5]
L2 = [10.45,10.65,10.78,10.43]
L3 = ['python','react','java','javascript']
L4 = [1001,'ravi','react',12000,10.45]
L5 = [100,10.45,'welcome',True,None]

# %%
print(L1)
print(L2)
print(L3)
print(L4)
print(L5)
# Out:
# [10, 20, 30, 40, 5]
# [10.45, 10.65, 10.78, 10.43]
# ['python', 'react', 'java', 'javascript']
# [1001, 'ravi', 'react', 12000, 10.45]
# [100, 10.45, 'welcome', True, None]

# %%
#type of anything if you get somthing then anything is created from something
type(L1)
# Out:
# list

# %%
#type of anything if you get type then anything is class
type(list)
# Out:
# type

# %%
#indexing and slicing

# %%
L1=[10,20,30,40,50,60,70,80,90]

# %%
print(L1)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 90]

# %%
L1[4]
# Out:
# 50

# %%
L1[-4]
# Out:
# 60

# %%
#slicing

# %%
L1
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 90]

# %%
print(L1[:])
print(L1[::])
print(L1[::1])
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 90]
# [10, 20, 30, 40, 50, 60, 70, 80, 90]
# [10, 20, 30, 40, 50, 60, 70, 80, 90]

# %%
print(L1[::2])
# Out:
# [10, 30, 50, 70, 90]

# %%
print(L1[::-1])
# Out:
# [90, 80, 70, 60, 50, 40, 30, 20, 10]

# %%
print(L1[:5])
# Out:
# [10, 20, 30, 40, 50]

# %%
print(L1[5:])
# Out:
# [60, 70, 80, 90]

# %%
print(L1[5::2])
# Out:
# [60, 80]

# %%
L1
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 90]

# %%
print(L1[5:2:-1])
# Out:
# [60, 50, 40]

# %%
print(L1[5:2:1])
# Out:
# []

# %% [raw]
# #reading list with for loop
# # for <var> in <iterableObject>:
#     statement

# %%
L1 = [100,200,300,400,500]

# %%
for i in L1:
    print(i)
# Out:
# 100
# 200
# 300
# 400
# 500

# %%
#list methods

# %%
pprint
# Out:
# Pretty printing has been turned OFF

# %%
dir(L1)
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
#list methods
'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort'

# %%
#append
#only one element we can add at end of the given list

# %%
L1 = [10,20,30,40,50]

# %%
L1.append(60)

# %%
L1
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
L1.append(70,80)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 L1.append(70,80)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
L1.append([70,80])

# %%
L1
# Out:
# [10, 20, 30, 40, 50, 60, [70, 80]]

# %%
L1.append("Python")

# %%
L1
# Out:
# [10, 20, 30, 40, 50, 60, [70, 80], 'Python']

# %%
#clear

# %%
L1 = [10,20,30,40,50]

# %%
print(L1)
print(L1.clear())
print(L1)
# Out:
# [10, 20, 30, 40, 50]
# None
# []

# %%
#copy

# %%
L1 = [10,20,30,40,50]

# %%
print(L1)
L2 = L1.copy()
print(L2)
# Out:
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]

# %%
print(id(L1))
print(id(L2))
# Out:
# 1702490851200
# 1702490947264

# %%
print(L1[0])
print(L2[0])
# Out:
# 10
# 10

# %%
print(id(L1[0]))
print(id(L2[0]))
# Out:
# 140717724181704
# 140717724181704

# %%
#count

# %%
L1 = [10,20,30,40,20,30,20,50,20,60,20,70]

# %%
L1.count(20)
# Out:
# 5

# %%
L1.count(30)
# Out:
# 2

# %%
#extend

# %%
L1 = [10,20,30]

# %%
print(L1)
L1.extend("python")
print(L1)
# Out:
# [10, 20, 30]
# [10, 20, 30, 'p', 'y', 't', 'h', 'o', 'n']

# %%
print(L1)
L1.extend(["react"])
print(L1)
# Out:
# [10, 20, 30, 'p', 'y', 't', 'h', 'o', 'n']
# [10, 20, 30, 'p', 'y', 't', 'h', 'o', 'n', 'react']

# %%
#extend required only one iterable object(string,range,list)
L1 = [10,20,30]
print(L1)
L1.extend(40,50,60)
print(L1)
# Out:
# [10, 20, 30]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 L1 = [10,20,30]
#       2 print(L1)
# ----> 3 L1.extend(40,50,60)
#       4 print(L1)
#
# TypeError: list.extend() takes exactly one argument (3 given)

# %%
L1 = [10,20,30]
print(L1)
L1.extend([40,50,60])
print(L1)
# Out:
# [10, 20, 30]
# [10, 20, 30, 40, 50, 60]

# %%
#index

# %%
L1 = [10,20,30,40,50,20,60,70,20,80,90]

# %%
L1.index(20)
# Out:
# 1

# %%
L1.index(20,3)
# Out:
# 5

# %%
#first 20 index number

# %%
L1.index(20)
# Out:
# 1

# %%
#second 20 index number
L1.index(20,L1.index(20)+1)
# Out:
# 5

# %%
#third 20 index number
L1.index(20,L1.index(20,L1.index(20)+1)+1)
# Out:
# 8

# %%
#find index number of element based on occurance number
# 20,7  ===> 8
# if not ==> no index number
#  L1.index(20,)

# %%
L1.count(20)
# Out:
# 3

# %%
L1
# Out:
# [10, 20, 30, 40, 50, 20, 60, 70, 20, 80, 90]

# %%
for i in L1:
    print(L1.index(i),i)
# Out:
# 0 10
# 1 20
# 2 30
# 3 40
# 4 50
# 1 20
# 6 60
# 7 70
# 1 20
# 9 80
# 10 90

# %%
#insert

# %%
L1 = [10,20,30,40,50]

# %%
L1
# Out:
# [10, 20, 30, 40, 50]

# %%
L1.insert(2,"react")

# %%
L1
# Out:
# [10, 20, 'react', 30, 40, 50]

# %%
#pop

# %%
L1
# Out:
# [10, 20, 'react', 30, 40, 50]

# %%
print(L1)
L1.pop()
print(L1)
# Out:
# [10, 20, 'react', 30, 40, 50]
# [10, 20, 'react', 30, 40]

# %%
print(L1)
L1.pop()
print(L1)
# Out:
# [10, 20, 'react', 30, 40]
# [10, 20, 'react', 30]

# %%
#remove
L1 = [10,20,30,40,50]
print(L1)
L1.remove(30)
print(L1)
# Out:
# [10, 20, 30, 40, 50]
# [10, 20, 40, 50]

# %%
#reverse

# %%
L1 = [10,20,30,40,50]
print(L1)
print(L1.reverse())
print(L1)
# Out:
# [10, 20, 30, 40, 50]
# None
# [50, 40, 30, 20, 10]

# %%
#sort : ascending order
L1 = [8,2,5,1,4,3]
print(L1)
L1.sort()
print(L1)
# Out:
# [8, 2, 5, 1, 4, 3]
# [1, 2, 3, 4, 5, 8]

# %%
#sort : descending order
L1 = [8,2,5,1,4,3]
print(L1)
L1.sort(reverse=True)
print(L1)
# Out:
# [8, 2, 5, 1, 4, 3]
# [8, 5, 4, 3, 2, 1]
