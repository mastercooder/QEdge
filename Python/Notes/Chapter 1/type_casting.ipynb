# %% [markdown]
# #casting and type casting in python
# #casting characters in coding languages
# %s    ==> it reads any data as string data
# %d    ==> it reads only integers or integer part from float data
# %f    ==> It reads only float data
# %r    ==> It treats every data as raw data

# %%
cr='python'
fee = 12000
t = 8.30

# %% [markdown]
# #what is casting?
# It is process of injecting variables data inside string data

# %%
print("welcome to cr coding")
# Out:
# welcome to cr coding

# %%
print("welcome to %s coding" %("java"))
print("welcome to %s coding" %(cr))
# Out:
# welcome to java coding
# welcome to python coding

# %%
print("welcome to %d coding" %(cr))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print("welcome to %d coding" %(cr))
#
# TypeError: %d format: a real number is required, not str

# %%
print("My course is %s and fees paid %d daily class time %f" %(cr,fee,t))
# Out:
# My course is python and fees paid 12000 daily class time 8.300000

# %%
print("My course is %s and fees paid %s daily class time %s" %(cr,fee,t))
# Out:
# My course is python and fees paid 12000 daily class time 8.3

# %%
print("My course is %s and fees paid %s daily class time %d" %(cr,fee,t))
# Out:
# My course is python and fees paid 12000 daily class time 8

# %%
print("My course is %s and fees paid %s daily class time %d" %(fee,cr,t))
# Out:
# My course is 12000 and fees paid python daily class time 8

# %%
#casting in python

# %%
print("My course name is {}".format("Gen-AI"))
# Out:
# My course name is Gen-AI

# %%
print("My course name is {}".format(cr))
# Out:
# My course name is python

# %%
print("My course is {} and fees paid {} daily class time {}".format(cr,fee,t))
# Out:
# My course is python and fees paid 12000 daily class time 8.3

# %%
print("My course is {} and fees paid {} daily class time {}".format(t,fee,cr))
# Out:
# My course is 8.3 and fees paid 12000 daily class time python

# %%
print("My course is {1} and fees paid {2} daily class time {0}".format(t,cr,fee))
# Out:
# My course is python and fees paid 12000 daily class time 8.3

# %%
#rawdata

# %%
print("welcome \nto \npython")
# Out:
# welcome
# to
# python

# %%
v1 = "welcome \nto \npython"

# %%
print(v1)
# Out:
# welcome
# to
# python

# %%
print("%s" %(v1))
# Out:
# welcome
# to
# python

# %%
print("{}".format(v1))
# Out:
# welcome
# to
# python

# %%
print("%r" %(v1))
# Out:
# 'welcome \nto \npython'

# %%
print(r"welcome \nto \npython")
# Out:
# welcome \nto \npython
