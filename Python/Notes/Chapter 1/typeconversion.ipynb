# %%
#convert the data from one type to another type

# %%
#string to int
#string to float

# %%
v1="100"

# %%
type(v1)
# Out:
# str

# %%
int(v1)
# Out:
# 100

# %%
float(v1)
# Out:
# 100.0

# %%
v1="10.45"

# %%
int(v1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 int(v1)
#
# ValueError: invalid literal for int() with base 10: '10.45'

# %%
float(v1)
# Out:
# 10.45

# %%
int(float(v1))
# Out:
# 10

# %%
v1="hi"

# %%
int(v1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 int(v1)
#
# ValueError: invalid literal for int() with base 10: 'hi'

# %%
float(v1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 float(v1)
#
# ValueError: could not convert string to float: 'hi'

# %%
#int to string
#int to float

# %%
v1 = 100

# %%
str(v1)
# Out:
# '100'

# %%
type(str(v1))
# Out:
# str

# %%
float(v1)
# Out:
# 100.0

# %%
type(float(v1))
# Out:
# float

# %%
#float to str
#float to int

# %%
v1=10.45

# %%
type(v1)
# Out:
# float

# %%
str(v1)
# Out:
# '10.45'

# %%
type(str(v1))
# Out:
# str

# %%
int(v1)
# Out:
# 10
