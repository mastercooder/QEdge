# %%
#understanding variables in python programming
#in python variables declaration not available only definition

# %%
a=10

# %%
#print is function to get value of variable
print(a)
# Out:
# 10

# %%
#id is also function to get the address of the variable
id(a)
# Out:
# 140727593313480

# %%
#type is function to get datattype of given variable or data
type(a)
# Out:
# int

# %%
b=10

# %%
print(b)
print(id(b))
print(type(b))
# Out:
# 10
# 140727593313480
# <class 'int'>

# %%
del a

# %%
m=100

# %%
print(m)
print(id(m))
# Out:
# 100
# 140727593316360

# %%
n=m

# %%
print(n)
print(id(n))
# Out:
# 100
# 140727593316360

# %%
del m

# %%
print(n)
print(id(n))
# Out:
# 100
# 140727593316360
