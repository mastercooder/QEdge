# %%
#data types
#int , float, str , boolean , NoneType, bytes , complex

# %%
type(100)
# Out:
# int

# %%
type(10.45)
# Out:
# float

# %%
type('welcome')
# Out:
# str

# %%
type("welcome")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type(None)
# Out:
# NoneType

# %%
a=None

# %%
type(a)
# Out:
# NoneType

# %%
type('welcome')
# Out:
# str

# %%
type(b'welcome')
# Out:
# bytes

# %%
'welcome'[0]
# Out:
# 'w'

# %%
b'welcome'[0]
# Out:
# 119

# %%
#ascii --> american standard code for information interchange
ord('w')
# Out:
# 119

# %%
ord('A')
# Out:
# 65

# %%
ord('0')
# Out:
# 48

# %%
ord('\n')
# Out:
# 10

# %%
#complex
pow(2,3)
# Out:
# 8

# %%
#square root of 4
pow(4,1/2)
# Out:
# 2.0

# %%
#square root of -4 is comple number
pow(-4,1/2)
# Out:
# (1.2246467991473532e-16+2j)

# %%
type(pow(-4,1/2))
# Out:
# complex

# %%
type(1.2246467991473532e-16+2j)
# Out:
# complex

# %%
(-4)**(1/2)
# Out:
# (1.2246467991473532e-16+2j)

# %%
type((-4)**(1/2))
# Out:
# complex
