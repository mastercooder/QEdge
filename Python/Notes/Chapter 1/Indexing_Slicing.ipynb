# %%
#indexing and slicing

# %%
#indexing ==> extracting element from iterable object with the help of index number
v1 = 'welcome'

# %%
print(v1)
# Out:
# welcome

# %%
print(v1[0])
print(v1[-1])
print(v1[-7])
print(v1[3])
# Out:
# w
# e
# w
# c

# %%
#slicing
#object[start=0:stop=end:step=+1]
#object[start=end:stop=0:step=-1]

# %%
v1 = 'welcome'

# %%
print(v1[:])
print(v1[::])
print(v1[::1])
print(v1[::2])
print(v1[::-1])
# Out:
# welcome
# welcome
# welcome
# wloe
# emoclew

# %%
print(v1[:3])
# Out:
# wel

# %%
print(v1[3:])
# Out:
# come

# %%
print(v1[2:5])
# Out:
# lco

# %%
print(v1[5:2:1])

# %%
print(v1[5:2:-1])
# Out:
# moc

# %%
print(v1[-5:-2:1])
# Out:
# lco

# %%
#check given string is pallendrome or not
str1 = "madam"

# %%
str1==str1[::-1]
# Out:
# True

# %%
str1 = input("Enter a string = ")
if str1==str1[::-1]:
    print("Given string/number is pallendrome")
else:
    print("Given string/number is not a pallendrome")
# Out:
# Enter a string =  4554
# Given string/number is pallendrome

# %%
contact = 9874589347

# %%
len(contact)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 len(contact)
#
# TypeError: object of type 'int' has no len()

# %%
len(str(contact))
# Out:
# 10
