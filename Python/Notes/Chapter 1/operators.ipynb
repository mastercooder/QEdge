# %%
#operators
#arithmetic operators(+,-,/,%,*,**,+=)
#relational operators(>,>=,<,<=,==,!=,is,not)
#list operator (in, not in)
#logical operators (and,or)

# %%
#arithmetic operators(+,-,/,%,*,**,+=)

# %%
print(2+2)
print(2+2.0)
print(2.0+2.0)
print(2.0+2)
print("hi"+" how are you?")

# %%
print(4+" how are you?")

# %%
print(" how are you?"+5)

# %%
print(5-2)
print(2*3)

# %%
print(2**3)
print(5**2)

# %%
print(8**(1/3))

# %%
#augmented assignment

# %%
a=5
a+=10 # a = a + 10
print(a)

# %%
a=5
a-=10 # a = a - 10
print(a)

# %%
a=5
a*=10 # a = a * 10
print(a)

# %%
a=2
a**=3 # a = a ** 3
print(a)

# %%
#relational operators(>,>=,<,<=,==,!=,is)
#using relational operators we write comparision statement
#any comparison statement will give you boolean value as result

# %%
print(5<7)
print(5>7)
print(5<=5)
print(5>=5)
# Out:
# True
# False
# True
# True

# %%
# == will compare only values
print(5==5)
print(5==5.0)
# Out:
# True
# True

# %%
# is will compare not only values as well as data types
# is called as strict comparison
print(5 is 5)
print(5 is  5.0)
# Out:
# True
# False

# %%
type(5)
# Out:
# int

# %%
type(5.0)
# Out:
# float

# %%
a=5
id(a)
# Out:
# 140709035877416

# %%
b=5.0
id(b)
# Out:
# 2599321713424

# %%
print(5==5.0)
print(5!=5.0)
# Out:
# True
# False

# %%
print(5 is 5.0)
print(5 is not 5.0)
# Out:
# False
# True

# %%
#97>98
print('a'>'b')
#98>97
print('a'<'b')
# Out:
# False
# True

# %%
ord('a')
# Out:
# 97

# %%
ord('b')
# Out:
# 98

# %%
#99<100
print('abc'<'abd')
#97>97
print('a'>'a')
# Out:
# True
# False

# %%
#list operator (in, not in)

# %%
'e' in 'welcome'
# Out:
# True

# %%
10 in 10010100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 10 in 10010100
#
# TypeError: argument of type 'int' is not iterable

# %%
"10" in "10010100"
# Out:
# True

# %%
10 in [1,2,3,10]
# Out:
# True

# %%
"10" not in "10010100"
# Out:
# False

# %%
#logical operators (and,or)

# %%
print(True and True)
print(False and True)
print(True and False)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
print(5==5 and 5 is not 5.0)
print(False and True)
print(True and False)
print(6>7 and 7 is 7.0)
# Out:
# True
# False
# False
# False

# %%
print(10 and 20)
# Out:
# 20

# %%
bool(10)
# Out:
# True

# %%
bool(20)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
print(0 and 20)
# Out:
# 0

# %%
bool(-46)
# Out:
# True

# %%
print(-46 and 20)
# Out:
# 20

# %%
print(True and False)
print(-56 and 0)
# Out:
# False
# 0

# %%
a = 5 and 6
print(a)
# Out:
# 6

# %%
a = 5 and 6 and 7 and 0 and 0.0 and 0 and 89
print(a)
# Out:
# 0

# %%
#logical (or)

# %%
print(True or True)
print(False or True)
print(True or False)
print(False or False)
# Out:
# True
# True
# True
# False

# %%
print(5==5 or 5 is not 5.0)
print(False or True)
print(True or False)
print(6>7 or 7 is 7.0)
# Out:
# True
# True
# True
# False

# %%
print(5 or 6)
print(7 or 0)
print(0 or 8)
print(0 or 0)
# Out:
# 5
# 7
# 8
# 0

# %%
a = 0 or 7
print(a)
# Out:
# 7

# %%
a = 7 or 6
print(a)
# Out:
# 7

# %%
a = True or False
print(a)
# Out:
# True

# %%
a = 6 or 8 or 0 or 0.0 or 4
print(a)
# Out:
# 6

# %%
a = 0 or 0.0 or 0 or 0.0 or 4
print(a)
# Out:
# 4
