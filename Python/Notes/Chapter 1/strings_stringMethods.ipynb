# %%
#how to handle strings

# %%
'welcome to python'
# Out:
# 'welcome to python'

# %%
"welcome to python"
# Out:
# 'welcome to python'

# %%
#string usually can not display singel quotes inside single quotes
'welcome python's classes'
# Out:
#   Cell In[3], line 2
#     'welcome python's classes'
#                              ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
#escape character
'welcome python\'s classes'
# Out:
# "welcome python's classes"

# %%
"welcome python's classes"
# Out:
# "welcome python's classes"

# %%
# double quotes
"welcome to python"s classes"
# Out:
#   Cell In[6], line 2
#     "welcome to python"s classes"
#                                 ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
"welcome to python\"s classes"
# Out:
# 'welcome to python"s classes'

# %%
'welcome to python"s classes'
# Out:
# 'welcome to python"s classes'

# %%
# write in multiple lines
'welcome 
to
python'
# Out:
#   Cell In[9], line 2
#     'welcome
#     ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
'welcome \
to \
python'
# Out:
# 'welcome to python'

# %%
'''
welcome
to
python
classes
'''
# Out:
# '\nwelcome\nto\npython\nclasses\n'

# %%
"""
welcome
to
python
classes
"""
# Out:
# '\nwelcome\nto\npython\nclasses\n'

# %%
#string methods

# %%
v1="welcome"

# %%
#capitalize

# %%
v1.capitalize()
# Out:
# 'Welcome'

# %%
"welcome to python".capitalize()
# Out:
# 'Welcome to python'

# %%
#title

# %%
"welcome to python".title()
# Out:
# 'Welcome To Python'

# %%
#lower

# %%
help(str.lower)
# Out:
# Help on method_descriptor:
#
# lower(self, /) unbound builtins.str method
#     Return a copy of the string converted to lowercase.

# %%
"WELCOME".lower()
# Out:
# 'welcome'

# %%
"welCOME to PYTHoN".lower()
# Out:
# 'welcome to python'

# %%
#casefold

# %%
help(str.casefold)
# Out:
# Help on method_descriptor:
#
# casefold(self, /) unbound builtins.str method
#     Return a version of the string suitable for caseless comparisons.

# %%
"WELCOME".casefold()
# Out:
# 'welcome'

# %%
"WELCOME tO PytHoN".casefold()
# Out:
# 'welcome to python'

# %%
str1="ß"
str2 = input("Enter string value ")
if str1.lower()==str2.lower():
    print("Success")
else:
    print("Failed")
# Out:
# Enter string value  ss
# Failed

# %%
str1="ß"
str2 = input("Enter string value ")
if str1.casefold()==str2.casefold():
    print("Success")
else:
    print("Failed")
# Out:
# Enter string value  ss
# Success

# %%
"ß".lower()
# Out:
# 'ß'

# %%
"ß".casefold()
# Out:
# 'ss'

# %%
"Σ".lower()
# Out:
# 'σ'

# %%
"Σ".casefold()
# Out:
# 'σ'

# %%
"Ω".casefold()
# Out:
# 'ω'

# %%
#upper

# %%
"welcome".upper()
# Out:
# 'WELCOME'

# %%
#center ==> 31 - 6 = 25
"python".center(31)
# Out:
# '             python            '

# %%
"python".center(31,"*")
# Out:
# '*************python************'

# %%
"python".center(7,"*")
# Out:
# '*python'

# %%
"welcome".center(8,"*")
# Out:
# 'welcome*'

# %%
"python".center(9,"*")
# Out:
# '**python*'

# %%
#count
"welcome".count("e")
# Out:
# 2

# %%
"weleceoeeme".count("e")
# Out:
# 6

# %%
"welcome".count("e",2)
# Out:
# 1

# %%
"weleceoeeme".count("e",6)
# Out:
# 3

# %%
#encode  ==> used to convert a string into bytess using a specified character
#            encoding
#data transmission (networking,APIs)
#File handling(binary mode)
#working with different character sets
#converting text - bytes for storage/processing
"welcome".encode()
# Out:
# b'welcome'

# %%
"welcome".encode(encoding='utf-8')
# Out:
# b'welcome'

# %%
"welcome".encode(encoding='utf-16')
# Out:
# b'\xff\xfew\x00e\x00l\x00c\x00o\x00m\x00e\x00'

# %%
"welcome".encode(encoding='utf-32')
# Out:
# b'\xff\xfe\x00\x00w\x00\x00\x00e\x00\x00\x00l\x00\x00\x00c\x00\x00\x00o\x00\x00\x00m\x00\x00\x00e\x00\x00\x00'

# %%
"welcome".encode(encoding='utf-64',errors='strict')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 "welcome".encode(encoding='utf-64',errors='strict')
#
# LookupError: unknown encoding: utf-64

# %%
"welcßome".encode(encoding='utf-16',errors='ignore')
# Out:
# b'\xff\xfew\x00e\x00l\x00c\x00\xdf\x00o\x00m\x00e\x00'

# %%
"welcßome".encode(encoding='utf-16')
# Out:
# b'\xff\xfew\x00e\x00l\x00c\x00\xdf\x00o\x00m\x00e\x00'

# %%
"welcßome".encode(encoding='utf-16',errors='replace')
# Out:
# b'\xff\xfew\x00e\x00l\x00c\x00\xdf\x00o\x00m\x00e\x00'

# %%
"welcome to ₹".encode()
# Out:
# b'welcome to \xe2\x82\xb9'

# %%
"welcome to ₹".encode("ascii",errors="strict")
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 "welcome to ₹".encode("ascii",errors="strict")
#
# UnicodeEncodeError: 'ascii' codec can't encode character '\u20b9' in position 11: ordinal not in range(128)

# %%
"welcome to ₹".encode("ascii",errors="ignore")
# Out:
# b'welcome to '

# %%
for i in "welcome".encode(encoding='utf-16'):
    print(i,end=" ")
# Out:
# 255 254 119 0 101 0 108 0 99 0 111 0 109 0 101 0

# %%
#endswith

# %%
"welcome".endswith('e')
# Out:
# True

# %%
"welcome to python".endswith("python")
# Out:
# True

# %%
#startswith

# %%
"welcome".startswith('w')
# Out:
# True

# %%
"welcome to python".startswith('welcome')
# Out:
# True

# %%
courses = ('python','javascript','react','django')

# %%
"i am looking for python".endswith(courses)
# Out:
# True

# %%
"i am looking for java".endswith(courses)
# Out:
# False

# %%
students = ('ramu','ravi','hari')

# %%
"ramu joined today class".startswith(students)
# Out:
# True

# %%
"koti joined today class".startswith(students)
# Out:
# False

# %%
courses = ('python','javascript','react','django')

# %%
print(f"welcome to {courses[1]}")
# Out:
# welcome to javascript

# %%
cr='react'

# %%
f"i am looking for {cr}".endswith(courses)
# Out:
# True

# %%
courses = ('python','javascript','react','django')

# %%
course = input("Please Enter which course do you want ?")
if f"i am looking for {course}".endswith(courses):
    print("Available")
else:
    print("Not Available")
# Out:
# Please Enter which course do you want ? django
# Available

# %%
#expand tabs
#\t for tab space by default it is 8spaces

# %%
"welcome\tto\tpython".expandtabs()
# Out:
# 'welcome to      python'

# %%
"welcome\tto\tpython".expandtabs(15)
# Out:
# 'welcome        to             python'

# %%
"welcome\tto\tpython".expandtabs(25)
# Out:
# 'welcome                  to                       python'

# %%
# find method finds index number of given element

# %%
"welcome".find('e')
# Out:
# 1

# %%
"welcome".find('t')
# Out:
# -1

# %%
"welcome".find('e',2)
# Out:
# 6

# %%
"raju@zohomail.in".find('@')
# Out:
# 4

# %%
"raju@zohomail.in".find('@')>=4
# Out:
# True

# %%
if "raju@zohomail.in".find('@')>=4:
    print("Valid Email")
else:
    print("Invalid Email")
# Out:
# Valid Email

# %%
"raju@king@zohomail.in".find('@')
# Out:
# 4

# %%
"raju@king@zohomail.in".count('@')
# Out:
# 2

# %%
email = "raju@zohomail.in"
if email.count('@')==1:
    if email.find('@')>=4:
        print("Valid Email")
    else:
        print("Email must have at least 4 characters")
else:
    print("Email must have only one @")
# Out:
# Valid Email

# %%
#rfind

# %%
help(str.rfind)
# Out:
# Help on method_descriptor:
#
# rfind(self, sub[, start[, end]], /) unbound builtins.str method
#     Return the highest index in S where substring sub is found, such that sub is contained within S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.
#     Return -1 on failure.

# %%
"welecome".rfind('e')
# Out:
# 6

# %%
"welecomeabc".rfind('e',2,6)
# Out:
# 3

# %%
#index finds index number of given element

# %%
"welcome".index("e")
# Out:
# 1

# %%
"welcome".index("t")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 "welcome".index("t")
#
# ValueError: substring not found

# %%
"welcome".rindex("e")
# Out:
# 6

# %%
#format

# %%
"welcome to {}".format('python')
# Out:
# 'welcome to python'

# %%
#format_map

# %%
student = {'sid':1001,'sname':'Ravi','fee':12500}

# %%
"I am {sname} my id is {sid} i have paid fee {fee}".format_map(student)
# Out:
# 'I am Ravi my id is 1001 i have paid fee 12500'

# %%
#

# %%
"welcome123".isalnum()
# Out:
# True

# %%
#

# %%
"welcome".isalpha()
# Out:
# True

# %%
"welcome123".isalpha()
# Out:
# False

# %%
#

# %%
"welcome".isascii()
# Out:
# True

# %%
"123".isascii()
# Out:
# True

# %%
"₹".isascii()
# Out:
# False

# %%
#

# %%
"123".isdecimal()
# Out:
# True

# %%
"welcome".isdecimal()
# Out:
# False

# %%
#

# %%
"123".isdigit()
# Out:
# True

# %%
"welcome".isdigit()
# Out:
# False

# %%
#

# %%
str1=""

# %%
str2="welcome"

# %%
str1.isidentifier()
# Out:
# False

# %%
str2.isidentifier()
# Out:
# True

# %%
#

# %%
"welcome".islower()
# Out:
# True

# %%
"WELCOME".islower()
# Out:
# False

# %%
#

# %%
"WELCOME".isupper()
# Out:
# True

# %%
'welcome'.islower()
# Out:
# True

# %%
#

# %%
"123".isnumeric()
# Out:
# True

# %%
"VI".isnumeric()
# Out:
# False

# %%
#

# %%
"welcome".isspace()
# Out:
# False

# %%
"welcome to python".isspace()
# Out:
# False

# %%
" ".isspace()
# Out:
# True

# %%
cnt=0
for i in "welcome to python":
    if i.isspace():
        cnt=cnt+1
print(cnt)
# Out:
# 2

# %%
#

# %%
"Welcome".istitle()
# Out:
# True

# %%
"Welcome to python".istitle()
# Out:
# False

# %%
"Welcome To Python".istitle()
# Out:
# True

# %%
#

# %%
"@".join("welcome")
# Out:
# 'w@e@l@c@o@m@e'

# %%
"python".join("1234")
# Out:
# '1python2python3python4'

# %%
"python".join(1234)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 "python".join(1234)
#
# TypeError: can only join an iterable

# %%
"python".join(['a','b','c'])
# Out:
# 'apythonbpythonc'

# %%
"python".join([1,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 "python".join([1,2,3])
#
# TypeError: sequence item 0: expected str instance, int found

# %%
"python".join("1234 ")
# Out:
# '1python2python3python4python '

# %%
#ljust  ==> leftside justification

# %%
"welcome".ljust(10)
# Out:
# 'welcome   '

# %%
"welcome".ljust(7)
# Out:
# 'welcome'

# %%
"welcome".ljust(3)
# Out:
# 'welcome'

# %%
#rjust ==> right side justification

# %%
"welcome".rjust(10)
# Out:
# '   welcome'

# %%
"welcome".rjust(25)
# Out:
# '                  welcome'

# %%
#lower

# %%
'WELCOME'.lower()
# Out:
# 'welcome'

# %%
#upper

# %%
'welcome'.upper()
# Out:
# 'WELCOME'

# %%
#lstrip ==> left side stripping means removing

# %%
"     welcome".lstrip()
# Out:
# 'welcome'

# %%
"******welcome".lstrip("*")
# Out:
# 'welcome'

# %%
"12343212321122322welcome".lstrip("1234")
# Out:
# 'welcome'

# %%
"******wel***come".lstrip("*")
# Out:
# 'wel***come'

# %%
#rstrip ==> right side stripping means removing

# %%
"welcome   ".rstrip()
# Out:
# 'welcome'

# %%
"wel**come******".rstrip("*")
# Out:
# 'wel**come'

# %%
#strip    ==> both sides

# %%
"    welcome     ".strip()
# Out:
# 'welcome'

# %%
"******welcome*****".strip("*")
# Out:
# 'welcome'

# %%
"******wel****come*****".strip("*")
# Out:
# 'wel****come'

# %%
#replace

# %%
"****w**el**come******".replace("*","")
# Out:
# 'welcome'

# %%
#

# %%
"welcome".split()
# Out:
# ['welcome']

# %%
"1001,ravi,python,12000".split(",")
# Out:
# ['1001', 'ravi', 'python', '12000']

# %%
"1001,ravi,python,12000".split(",",2)
# Out:
# ['1001', 'ravi', 'python,12000']

# %%
"1001,ravi,python,12000,50,kumar,city".split(",",2)
# Out:
# ['1001', 'ravi', 'python,12000,50,kumar,city']

# %%
"1001,ravi,python,12000,50,kumar,city".split(",",3)
# Out:
# ['1001', 'ravi', 'python', '12000,50,kumar,city']

# %%
student = "1001,ravi,python,12000".split(",")

# %%
print(student[0])
print(student[1])
print(student[2])
print(student[3])
# Out:
# 1001
# ravi
# python
# 12000

# %%
#rsplit

# %%
"1001,ravi,python,12000,50,kumar,city".rsplit(",")
# Out:
# ['1001', 'ravi', 'python', '12000', '50', 'kumar', 'city']

# %%
"1001,ravi,python,12000,50,kumar,city".rsplit(",",3)
# Out:
# ['1001,ravi,python,12000', '50', 'kumar', 'city']

# %%
#removeprefix

# %%
"www.mysite.com".removeprefix("www.")
# Out:
# 'mysite.com'

# %%
#removesuffix

# %%
"www.mysite.com".removesuffix(".com")
# Out:
# 'www.mysite'

# %%
"www.mysite.com".removeprefix("www.").removesuffix(".com")
# Out:
# 'mysite'

# %%
domain = "www.mysite.com".removeprefix("www.").removesuffix(".com")

# %%
domain
# Out:
# 'mysite'

# %%
#

# %%
"welcome to python".title()
# Out:
# 'Welcome To Python'

# %%
#swapcase()

# %%
"wElCoMe".swapcase()
# Out:
# 'WeLcOmE'

# %%
#
help(str.splitlines)
# Out:
# Help on method_descriptor:
#
# splitlines(self, /, keepends=False) unbound builtins.str method
#     Return a list of the lines in the string, breaking at line boundaries.
#
#     Line breaks are not included in the resulting list unless keepends is given and
#     true.

# %%
"welcome \
to \
python".splitlines()
# Out:
# ['welcome to python']

# %%
"welcome \nto \npython".splitlines()
# Out:
# ['welcome ', 'to ', 'python']

# %%
"welcome \n to \npython".splitlines(keepends=True)
# Out:
# ['welcome \n', ' to \n', 'python']

# %%
help("welcome,to,python".partition)
# Out:
# Help on built-in function partition:
#
# partition(sep, /) method of builtins.str instance
#     Partition the string into three parts using the given separator.
#
#     This will search for the separator in the string.  If the separator is found,
#     returns a 3-tuple containing the part before the separator, the separator
#     itself, and the part after it.
#
#     If the separator is not found, returns a 3-tuple containing the original string
#     and two empty strings.

# %%
"welcome to python in Qedge".partition("to")
# Out:
# ('welcome ', 'to', ' python in Qedge')
