# %%
#assignments

# %%
1. Division calculator
    write a program that:
        1. takes 2 numbers from the user
        2. divides them
        3. handles division by zero using try-except

# %%
a=10
b=0

# %%
a/b
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a/b
#
# ZeroDivisionError: division by zero

# %%
2. Number validation
    1. ask the user to enter age
    2. if user enters text instead of number , handle it using exception

# %%
3. file handling exception
    1. Read a file called data.txt
    2. if file does not exist , handle with proper exception

# %%
4. Multiple exceptions
    Handle 
        1. ZeroDivisionError
        2. ValueError

# %%
5. CustomException
    1. create your own exception class
        InvalidAgeError

# %%
6. write a function to find given number is prime or not
    function name ==> is_prime(7)

# %%
7. write a recusive function for Fibonacci series
    function name ==> fib(45)

# %%
8. Find mobile number
    write a function to find 10 digit numbers from given text

# %%
9. find mobile number with country code
    write function to find +915674564647

# %%
10. extract dates 
    write a function to find the dates from given text
        10-12-2025
        04-mar-2026

# %%
11. find 3 consecutive zeros

# %%
12. password validation
    pasword rules
        1. minimum 8 characters
        2. 1 upper case
        3. 1 lower case
        4. 1 digit
        5. 1 special character

# %%
13. Develop mini project
    create user Registration from validator using
        1. functions
        2. exceptions
        3. regex

    validate
        name
        email
        phone
        password

# %%
14 .find given number even or odd

# %%
15. Largest of 3 numbers
    input -->  10, 15, 25
    output --> 25

# %%
16. write a function to Reverse a string

# %%
17. count Vowels from given string text

# %%
18. find given number is Palindrome number or not

# %%
19. find give text is Palindrome text or not
