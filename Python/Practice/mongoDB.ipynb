# %%
from pymongo import MongoClient

client = MongoClient("mongodb+srv://master_coder:14422@cluster0.c64vzro.mongodb.net/?appName=Cluster0")
# Out:
# List of Databases:  ['mysiteDB', 'sample_mflix', 'admin', 'local']
# Database(MongoClient(host=['ac-nnnkdo6-shard-00-00.c64vzro.mongodb.net:27017', 'ac-nnnkdo6-shard-00-01.c64vzro.mongodb.net:27017', 'ac-nnnkdo6-shard-00-02.c64vzro.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='Cluster0', authsource='admin', replicaset='atlas-jnt2y8-shard-0', tls=True), 'mysiteDB')

# %%
dbname = client.list_database_names()
print("List of Databases: ", dbname)

db = client['mysiteDB']

collection = db.list_collection_names()
print("List of Collections: ", collection)

collection = db['student']

query1 = {'sid': 1005}

data = collection.find_one(query1)
print("query1: ", data)


for i in data:
    print(i)
# Out:
# List of Databases:  ['mysiteDB', 'sample_mflix', 'admin', 'local']
# List of Collections:  ['student']
# query1:  {'_id': ObjectId('6a32a46e590ca300b4286dd1'), 'sid': 1005, 'sname': 'Rahul', 'course': 'Python', 'fee': 4500}
# _id
# sid
# sname
# course
# fee

# %%
type(query1)
# Out:
# dict

# %%
type(data)
# Out:
# dict

# %%
print(data['sname'])
# Out:
# Rahul

# %%
from pymongo import MongoClient

client = MongoClient("mongodb+srv://master_coder:14422@cluster0.c64vzro.mongodb.net/?appName=Cluster0")

# %%
dbname = client.list_database_names()
dbname
# Out:
# ['mysiteDB', 'sample_mflix', 'admin', 'local']

# %%
db = client['mysiteDB']

collection = db.list_collection_names()
collection
# Out:
# ['student']

# %%
collection = db['student']

data = collection.find()

# %%
for i in data:
    print(i)
# Out:
# {'_id': ObjectId('6a3299677375b45ecbcc3e15'), 'sid': '1001', 'sname': "'Tejesh'", 'course': "'Python'"}
# {'_id': ObjectId('6a3299c97375b45ecbcc3e16'), 'sid': '1002', 'sname': "'Jayesh'", 'course': "'React'", 'fee': '6000', 'trainer': "'kumar'"}
# {'_id': ObjectId('6a32a2b5590ca300b4286dcf'), 'sid': 1003, 'sname': 'hari', 'course': 'python', 'fee': 10500, 'email': 'hari@zohomail.in', 'city': 'chennai'}
# {'_id': ObjectId('6a32a46e590ca300b4286dd0'), 'sid': 1004, 'sname': 'Koti', 'course': 'FastAPI', 'fee': 3500}
# {'_id': ObjectId('6a32a46e590ca300b4286dd1'), 'sid': 1005, 'sname': 'Rahul', 'course': 'Python', 'fee': 4500}
# {'_id': ObjectId('6a32a46e590ca300b4286dd2'), 'sid': 1006, 'sname': 'Tushar', 'course': 'MongoDB', 'fee': 5000}
# {'_id': ObjectId('6a32a46e590ca300b4286dd3'), 'sid': 1007, 'sname': 'Rajesh', 'course': 'Django', 'fee': 5500}
# {'_id': ObjectId('6a32a46e590ca300b4286dd4'), 'sid': 1008, 'sname': 'Suresh', 'course': 'React', 'fee': 6000}
# ...
