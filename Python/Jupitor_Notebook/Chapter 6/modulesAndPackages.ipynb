# %% [markdown]
# <h1 align='center'><b><u>Modules And Packages</u></b></h1>
# <hr>
#
# <i><b>
#     <p>Modules is .py file which contain classes and functions</p>
#     <p>Package is folder which contains .py files</p>
# </b></i>

# %%
import mod1

# %%
mod1.f1()
# Out:
# 'm1 of module mod1'

# %%
mod1.greet('Good Morning')
# Out:
# 'Good Morning'

# %%
mod1.add(100, 200)
# Out:
# 300

# %%
xobj1 = mod1.x()

# %%
xobj1.b
# Out:
# 222

# %%
xobj1.m1()
# Out:
# 'm1 of class x'

# %%
from mod1 import f1

f1()
# Out:
# 'm1 of module mod1'

# %%
from mod1 import greet

greet('hello')
# Out:
# 'hello'

# %%
from mod1 import *

print(f1())

print(greet('Good Morning'))

print(add(10, 20))
# Out:
# m1 of module mod1
# Good Morning
# 30

# %%
xobj1 = x()

# %%
print(xobj1.a)
print(xobj1.b)
print(xobj1.m1())
# Out:
# 111
# 222
# m1 of class x

# %%
from mod1 import *

# %%
m
# Out:
# 500

# %% [markdown]
# <hr><br>
# <h2><b>1. <u>Working With packages</u></b></h2>
# <br>
#
# <h3><b>i. <u>1st Method</u></b></h3>

# %%
# It will not work
import Pack1

# %%
from Pack1 import pack1Mod1

# %%
pack1Mod1.f11()
# Out:
# 'm1 of module mod1'

# %%
pack1Mod1.mult(2, 3)
# Out:
# 6

# %% [markdown]
# <h3><b>ii. <u>2nd Method</u></b></h3>

# %%
from Pack1.pack1Mod1 import wish

# %%
wish('welcome')
# Out:
# 'welcome'

# %% [markdown]
# <h3><b>iii. <u>3rd Method</u></b></h3>

# %%
import Pack1

# %%
Pack1.pack1Mod1.f11()
# Out:
# 'm1 of module mod1'

# %%
from Pack1 import *

# %%
pack1Mod1.f11()
# Out:
# 'm1 of module mod1'

# %%
pack1Mod2.f22()
# Out:
# 'f22 function if module pack1Mod2'
