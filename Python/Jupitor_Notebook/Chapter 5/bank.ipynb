# %% [markdown]
# <h1 align='center'><b><u>Bank Project</u></b></h1>
# <hr>
# <h3><b><u>Requirement's</u></b></h3>
# <b><i>
# <ol>
#     <li>Create a class with account</li>
#     <li>Implement Opeartions such as</li>
#     <ul>
#         <li>Create Account</li>
#         <li>Get Balance</li>
#         <li>Deposit</li>
#         <li>Withdraw</li>
#         <li>Transfer amount from one valid account to another valid account</li>
#         <li>Add all balances to main bank balance</li>
#     </ul>
# </ol>
# </i></b>

# %%
class account:
    acc1 = 9176402776
    acc2 = 9176443084
    acc3 = 9176355773
    
    def __init__(self):
        print("Welcome To United Bank")
        
    def createAccount(self, acc4):
        self.acc4 = acc4
        print("You account has been Created Successfully!")
        
        
ub_bank = account()
ub_bank.createAccount(2345623456)
# Out:
# Welcome To United Bank
# You account has been Created Successfully!
