# %% [markdown]
# <h1><b><u>Class Object</u></b></h1>
#
# ```json
# 1. What is a class?
# A Class is like a Temlate or paper plan for house used to create objects(house)
#
# ```
#
# Video Attended: 20:10
