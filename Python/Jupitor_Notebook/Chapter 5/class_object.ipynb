# %% [markdown]
# <h1 align="center"><b><u>Class and Object in Python</u></b></h1>
#
# <hr>
#
# <h2><b><u>What is a Class?</u></b></h2>
#
# <ul>
#     <li>A <b>Class</b> is a blueprint or template used to create objects.</li>
#     <li>Just like a house blueprint is used to build multiple houses, a class is used to create multiple objects.</li>
#     <li>A class contains <b>Properties</b> and <b>Activities</b>.</li>
#     <li>In Python:
#         <ul>
#             <li><b>Properties</b> are called <b>Attributes</b>.</li>
#             <li><b>Activities</b> are called <b>Methods</b>.</li>
#         </ul>
#     </li>
# </ul>
#
# <p><b>A Class contains two components:</b></p>
#
# <ol>
#     <li><b>Attributes</b> (Variables)</li>
#     <li><b>Methods</b> (Functions)</li>
# </ol>
#
# <ul>
#     <li>Attributes store data related to an object.</li>
#     <li>Methods define the behavior of objects created from the class.</li>
#     <li>Every object created from a class has access to its attributes and methods (except private members).</li>
# </ul>
#
# <hr>
#
# <h2><b><u>Class Syntax</u></b></h2>
#
# <pre>
# class ClassName(object):
#     attributes
#     methods
# </pre>
#
# <hr>
#
# <h2><b><u>Creating a Class</u></b></h2>
#
# ```json
# class <className>:
#     <attr1> = <value1>
#     <attr2> = <value2>
#
#     def <methodName>(parameters):
#         val1 = value1
#         val2 = value2
#         statement1
#         statement2
#         ...
#         ...
#         return <output>
#
#     def <methodName>(parameters):
#         val1 = value1
#         val2 = value2
#         statement1
#         statement2
#         ...
#         ...
#         return <output>
# ```
#
# <hr>
#
# <h2><b><u>Object Creation Syntax</u></b></h2>
#
# <pre>
# objectName = ClassName(arguments)
# </pre>
#
# <hr>
#
# <h2><b><u>Example</u></b></h2>
#
# <pre>
# class Student:
#
#     college = "Kalinga University"
#     course = "BCA AI-ML"
#
#     def display(self):
#         print("Student Details")
#
# s1 = Student()
# s2 = Student()
# </pre>
#
# <p>
# Here, <b>s1</b> and <b>s2</b> are objects (instances) of the <b>Student</b> class.
# </p>
#
# <hr>
#
# <h2><b><u>Class vs Object</u></b></h2>
#
# <table>
#     <tr>
#         <th>Class</th>
#         <th>Object</th>
#     </tr>
#     <tr>
#         <td>Blueprint / Template</td>
#         <td>Instance of a Class</td>
#     </tr>
#     <tr>
#         <td>Contains Attributes and Methods</td>
#         <td>Uses Attributes and Methods</td>
#     </tr>
#     <tr>
#         <td>Logical Entity</td>
#         <td>Physical Entity</td>
#     </tr>
#     <tr>
#         <td>Created Once</td>
#         <td>Can Create Multiple Objects</td>
#     </tr>
# </table>
#
# <hr>
#
# <h2><b><u>Quick Summary</u></b></h2>
#
# <ul>
#     <li><b>Class</b> → Blueprint or Template</li>
#     <li><b>Object</b> → Instance of a Class</li>
#     <li><b>Attribute</b> → Variable inside a Class</li>
#     <li><b>Method</b> → Function inside a Class</li>
# </ul>
#
# <h2><b>1. <u>Sample Class Creation and Object Creation</u></b></h2>

# %%
class x:
    a = 100
    b = 200
    
    #Object Method if you pass 'self' in the function 
    def m1(self):
        return 'm1 of class x'
    
    def m2(self):
        return 'm2 of class x'

# %%
x.a
# Out:
# 100

# %%
x.b
# Out:
# 200

# %%
x.m1()
x.m2()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 x.m1()
#       2 x.m2()
#
# TypeError: x.m1() missing 1 required positional argument: 'self'

# %%
xObj1 = x()

# %%
print(xObj1.a)
print(xObj1.b)
# Out:
# 100
# 200

# %%
xObj1.m1()
# Out:
# 'm1 of class x'

# %%
xObj1.m2()
# Out:
# 'm2 of class x'

# %%
class x:
    a = 100
    
    # Not a object method as no 'self' is passed in the function
    def m1():
        return 'm1 of class x'

# %%
x.m1()
# Out:
# 'm1 of class x'

# %%
xobj1 = x()

# %%
xobj1.m1()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 xobj1.m1()
#
# TypeError: x.m1() takes 0 positional arguments but 1 was given

# %% [markdown]
# <h3>
# <i><b>
# <li>Understanding class attributes and object attributes</li>
# <li>Relationship between class attributes and object atrributes</li>
# </b></i>
# </h3>

# %%
class x:
    a = 100
    b = 200
    
    def m1(self):
        return 'm1 of class x'
    
    def m2(self):
        return 'm2 of class x'

# %%
x.a
# Out:
# 100

# %%
x.b
# Out:
# 200

# %%
xobj1 = x()

# %%
xobj1.m1()
# Out:
# 'm1 of class x'

# %%
xobj1.m2()
# Out:
# 'm2 of class x'

# %%
x.a = 110

# %%
x.a
# Out:
# 110

# %%
xobj1.a
# Out:
# 110

# %%
xobj1.a = 120

# %%
xobj1.a
# Out:
# 120

# %%
x.a = 130

# %%
x.a
# Out:
# 130

# %%
xobj1.a
# Out:
# 120

# %%
class x:
    a = 100
    
    def m1(self):
        return 'm1 of class x'

# %%
xObj1 = x()

# %%
x.a
# Out:
# 100

# %%
xObj1.a
# Out:
# 100

# %%
xObj1.a = 100

# %%
x.a
# Out:
# 100

# %%
x.a = 120

# %%
x.a
# Out:
# 120

# %%
xObj1.a
# Out:
# 100

# %% [markdown]
# <h2><b>2. <u>Access Class Attribute inside method</u></b></h2>

# %%
class x:
    a = 100  # Class Attribute
    
    def m1(self):
        return "m1 of class x", a

# %%
xobj1 = x()

# %%
xobj1.a
# Out:
# 100

# %%
xobj1.m1()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 xobj1.m1()
#
# Cell In[67], line 5, in x.m1(self)
#       4 def m1(self):
# ----> 5     return "m1 of class x", a
#
# NameError: name 'a' is not defined

# %%
class x:
    a = 100
    
    def m1(self):
        a = 120     # variable inside method only(scope)
        return 'm1 of class x', self.a, a

# %%
xobj1 = x()

# %%
xobj1.m1()
# Out:
# ('m1 of class x', 100, 120)

# %% [markdown]
# <h2><b>3. <u>Create Object Attribute</u></b></h2>

# %%
class x:
    a = 100
    
    def m1(self):
        return 'm1 of class x'

# %%
xobj1 = x

# %%
x.a
# Out:
# 100

# %%
xobj1.a
# Out:
# 100

# %% [markdown]
# <h3><b>i. Adding new class attribute inside class after class creation</b></h3>

# %%
x.b = 200

# %%
x.b
# Out:
# 200

# %%
xobj1.b
# Out:
# 200

# %% [markdown]
# <h3><b>ii. Adding new attrribute inside object as object attribute</b></h3>
# <li>Adding new attribute inside object that is avalable inside object not in class</li>

# %%
class x:
    a = 100
    
    def m1(self):
        return "m1 of class x"

# %%
xobj1 = x()

# %%
x.a
# Out:
# 100

# %%
xobj1.a
# Out:
# 100

# %%
xobj1.b = 200

# %%
x.b
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 x.b
#
# AttributeError: type object 'x' has no attribute 'b'

# %%
xobj1.b
# Out:
# 200

# %% [markdown]
# <h3><b>iii. Another way to add/create object attribute inside the method </b></h3>

# %%
class x:
    a = 100     # class attribute
    
    def m1(self):
        a = 120
        self.b = 200
        return 'm1 of class x', self.a, self.b, a

# %%
xobj1 = x()

# %%
xobj1.m1()
# Out:
# ('m1 of class x', 100, 200, 120)

# %%
xobj1.b
# Out:
# 200

# %% [markdown]
# <h3><b>iv. Creating new object attribute inside method dynamically</b></h3>

# %%
class x:
    a = 100
    
    def m1(self, b):
        self.b = b
        return 'm1 of class x', self.a, self.b

# %%
xobj1 = x()

# %%
x.a
# Out:
# 100

# %%
xobj1.a
# Out:
# 100

# %%
xobj1.m1(200)
# Out:
# ('m1 of class x', 100, 200)

# %%
xobj1.b
# Out:
# 200

# %%
class x:
    a = 100
    
    def m1(self, a):
        self.a = a
        return 'm1 of class x', self.a

# %%
xobj1 = x()

# %%
xobj1.a
# Out:
# 100

# %%
x.a
# Out:
# 100

# %%
xobj1.m1(120)
# Out:
# ('m1 of class x', 120)

# %%
xobj1.a
# Out:
# 120

# %%
x.a
# Out:
# 100

# %% [markdown]
# <h3><b><i>Color Car</i></b></h3>

# %%
class Car:
    tyres = 4
    color = 'red'
    
    def start(self):
        return "{} color car started".format(self.color)
    
    def stop(self):
        return '{} color car stopped'.format(self.color)

# %%
car1 = Car()

# %%
print(car1.tyres)
print(car1.color)
# Out:
# 4
# red

# %%
car1.start()
# Out:
# 'red color car started'

# %%
car1.stop()
# Out:
# 'red color car stopped'

# %%
car2 = Car()

# %%
car3 = Car()

# %%
car3.color
# Out:
# 'red'

# %%
car3.color = 'blue'

# %%
car3.color
# Out:
# 'blue'

# %%
class Car:
    tyres = 4
    color = 'red'
    
    def start(self):
        return "{} color car started".format(self.color)
    
    def stop(self):
        return '{} color car stopped'.format(self.color)
    
    def changeColor(self, color):
        self.color = color
        return 'Your car color changed to {}'.format(self.color)

# %%
car1 = Car()
car2 = Car()

# %%
car1.color
# Out:
# 'red'

# %%
car1.changeColor('Blue')
# Out:
# 'Your car color changed to Blue'

# %%
car1.color
# Out:
# 'Blue'

# %%
car2.color
# Out:
# 'red'

# %% [markdown]
# <h2><b>4. <u>Magic Methods</u></b></i></h3>
#
# <h3><b>i. Constructor in Python: __init__</b></h3>
# <li><b>Syntax:</b> def __init__(self)</li>
# <li>A constructor is a special method that is automatically called when an object is created.</li>
# <li><b>It Shoud return NULL</b></li>

# %%
class x:
    a = 100
    def __init__(self):
        print('object created of x class')

# %%
xobj1 = x()
# Out:
# object created of x class

# %%
class x:
    a = 100
    def __init__(self, b):
        print(b)

# %%
xobj1 = x(100)
# Out:
# 100

# %%
x.a
# Out:
# 100

# %%
class Car:
    tyres = 4
    
    def __init__(self, color, music='Poineer'):
        self.color = color
        print("Car created with {} color".format(self.color))
        self.music = music
    
    def start(self):
        return "{} color car started".format(self.color)
    
    def stop(self):
        return '{} color car stopped'.format(self.color)
    
    def changeColor(self, color):
        self.color = color
        return 'Your car color changed to {}'.format(self.color)

# %%
car1 = Car('Blue')
# Out:
# Car created with Blue color

# %%
car1.color
# Out:
# 'Blue'

# %%
car1.music
# Out:
# 'Poineer'

# %%
car2 = Car('Red', 'sony')
# Out:
# Car created with Red color

# %%
car2.color
# Out:
# 'Red'

# %%
car2.music
# Out:
# 'sony'

# %%
car2.changeColor('yellow')
# Out:
# 'Your car color changed to yellow'

# %%
car2.color
# Out:
# 'yellow'

# %%
car1.color
# Out:
# 'Blue'

# %% [markdown]
# <h3><b><i>Q. What is self in method creation of class</i></b></h3>

# %%
# You can use any name of parameter of the 1st parameter but its recommanded to use self to reduce confustion

class x:
    a = 100
    
    def m1(tejesh):
        print(id(tejesh))
        return tejesh.a

# %%
xobj1 = x()

# %%
id(xobj1)
# Out:
# 2898727972416

# %%
xobj1.m1()
# Out:
# 2898727972416
# 100

# %%
class x:
    a = 100
    
    def m1(self):
        return self.a
    
    def m2(self, a):
        self.a = a
        return self.a

# %%
xobj1 = x()

# %%
xobj1.a
# Out:
# 100

# %%
xobj1.m1()
# Out:
# 100

# %% [markdown]
# <h3><b>ii. __str__</b></h3>
# <li>It must return a string</li>
# <li>What is __str__() special method</li>

# %%
class Car:
    tyres = 4
    maker = 'TATA'
    
    def __init__(self, color, music='Poineer'):
        self.color = color
        print("Car created with {} color".format(self.color))
        self.music = music
        
    
    def start(self):
        return "{} color car started".format(self.color)
    
    def stop(self):
        return '{} color car stopped'.format(self.color)
    
    def changeColor(self, color):
        self.color = color
        return 'Your car color changed to {}'.format(self.color)
    
    
    def __str__(self):
        return self.maker

# %%
car1 = Car('red')
# Out:
# Car created with red color

# %%
print(car1)
# Out:
# TATA

# %% [markdown]
# <h3><b>ii. Documental String</b></h3>

# %%
class x:
    '''
        this is documental string to
        explain about class x
        and it's functionalities
    '''
    a = 100
    
    def m1(self):
        """
            this is method m1
            of class x
            and return a
            string value
        """
        
        return 'm1 of class x'

# %%
print(x.__doc__)
# Out:
# this is documental string to
# explain about class x
# and it's functionalities

# %%
xobj1 = x()

# %%
print(xobj1.__doc__)
# Out:
# this is documental string to
# explain about class x
# and it's functionalities

# %% [markdown]
# <h3><b><i>__dict__</i></b></h3>

# %%
class x:
    a = 10
    b = 20
    
    def m1(self):
        return 'm1 of class x'
    
    def m2(self):
        return 'm2 of class x'

# %%
print(x.__dict__)
# Out:
# {'__module__': '__main__', '__firstlineno__': 1, 'a': 10, 'b': 20, 'm1': <function x.m1 at 0x000002A2EA26D6C0>, 'm2': <function x.m2 at 0x000002A2EA26FA60>, '__static_attributes__': (), '__dict__': <attribute '__dict__' of 'x' objects>, '__weakref__': <attribute '__weakref__' of 'x' objects>, '__doc__': None}

# %%
print(x.__dict__.keys())
# Out:
# dict_keys(['__module__', '__firstlineno__', 'a', 'b', 'm1', 'm2', '__static_attributes__', '__dict__', '__weakref__', '__doc__'])

# %%
xobj1 = x()

# %%
print(xobj1.__dict__)
# Out:
# {}

# %%
xobj1.c = 300

# %%
print(xobj1.__dict__)
# Out:
# {'c': 300}

# %% [markdown]
# <h2><b>5. <u>Remaning Function</u></b></i></h3>
# <h3><b>i. __class__( )</b></h3>

# %%
xobj1.__class__
# Out:
# __main__.x

# %% [markdown]
# <h3><b>ii. __module__( )</b></h3>

# %%
xobj1.__module__
# Out:
# '__main__'

# %% [markdown]
# <h3><b>iii. __sizeof__( )</b></h3>

# %%
xobj1.__sizeof__()
# Out:
# 16

# %%
# Object will ocupi the memory
x.__sizeof__(xobj1)
# Out:
# 16

# %% [markdown]
# <h3><b>iv. __getattribute__( )</b></h3>

# %%
class x:
    a = 100
    b = 200
    
    def m1(self):
        return 'm1 of class x'
    
    def m2(self):
        return 'm2 of class x'

# %%
xobj1 = x()

# %%
print(xobj1.__getattribute__('a'))
print(xobj1.__getattribute__('a'))
# Out:
# 100
# 100

# %%
x.a
# Out:
# 100

# %%
# You will need object to get the data from __getattribute__()
x.__getattribute__(xobj1, 'a')
# Out:
# 100

# %% [markdown]
# <h3><b>v. __setattr__( )</b></h3>

# %%
class x:
    a = 100
    b = 200
    
    def m1(self):
        return 'm1 of class x'
    
    def m2(self):
        return 'm2 of class x'

# %%
xobj1 = x()

# %%
xobj1.__setattr__('c', 300)

# %%
xobj1.c
# Out:
# 300

# %%
# Object is need to use __setattr__()
x.__setattr__(xobj1, 'd', 400)

# %%
xobj1.d
# Out:
# 400

# %% [markdown]
# <h3><b>vi. __delattr__( )</b></h3>

# %%
class x:
    a = 100
    b = 200
    
    def m1(self):
        return 'm1 of class x'
    
    def m2(self):
        return 'm2 of class x'

# %%
xobj1 = x()

# %%
xobj1.__delattr__('b')
x.__delattr__('b')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 xobj1.__delattr__('b')
#       2 x.__delattr__('b')
#
# AttributeError: 'x' object has no attribute 'b'

# %%
x.__delattr__(xobj1, 'b')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 x.__delattr__(xobj1, 'b')
#
# AttributeError: 'x' object has no attribute 'b'

# %%
xobj1.__setattr__('c', 300)

# %%
xobj1.__dict__
# Out:
# {'c': 300}

# %%
# If you have added attributes then only we can delete it with __delattr__()

xobj1.__delattr__('c')

# %%
xobj1.__dict__
# Out:
# {}

# %% [markdown]
# <h2><b>6. <u>Adding attributes inside class using in-build functions</u></b></h2>
#
# <b><i>
# <ol>
#     <li>getattr</li>
#     <li>setattr</li>
#     <li>hasattr</li>
#     <li>delattr</li>
#     <li>isinstance</li>
#     <li>issubclass</li>
#     <li>classmethod</li>
#     <li>staticmethod</li>
#     <li>super</li>
# </ol>
# </i></b>

# %%
class x:
    a = 100
    
    def m1(self):
        return 'm1 of class x'

# %%
x.a
# Out:
# 100

# %%
xobj1 = x()

# %%
xobj1.__dict__
# Out:
# {}

# %% [markdown]
# <h3><b>i. getattr</b></h3>

# %%
getattr(x, 'a')
# Out:
# 100

# %% [markdown]
# <h3><b>ii. setattr</b></h3>

# %%
setattr(x, 'b', 200)

# %%
x.b
# Out:
# 200

# %%
xobj1.b
# Out:
# 200

# %%
setattr(xobj1, 'c', 300)

# %%
xobj1.c
# Out:
# 300

# %% [markdown]
# <h3><b>iii. hasattr</b></h3>

# %%
hasattr(x, 'c')
# Out:
# False

# %%
hasattr(xobj1, 'c')
# Out:
# True

# %% [markdown]
# <h3><b>iv. delattr</b></h3>

# %%
delattr(x, 'b')

# %%
# False tell us there is no attributes with the name
hasattr(x, 'b')
# Out:
# False

# %% [markdown]
# <h3><b>v. isinstance</b></h3>

# %%
class c1:
    a = 100

# %%
c1obj1 = c1()

# %%
class c2:
    b = 200

# %%
c2obj1 = c2()

# %%
print(isinstance(c1obj1, c1))
print(isinstance(c1obj1, c2))
print(isinstance(c2obj1, c1))
print(isinstance(c2obj1, c2))
# Out:
# True
# False
# False
# True
