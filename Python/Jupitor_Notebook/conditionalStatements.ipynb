# %%
i = 1
while(i<=5):
    print(i)
    i = i+1
print("Done")
# Out:
# 1
# 2
# 3
# 4
# 5
# Done

# %%
# How to change the default Seperator
print(10, 20, 30, 40, 50, sep="||")
# Out:
# 10||20||30||40||50

# %%
print("welcome", end="")
print(" to", end="")
print(" python ", end="")
# Out:
# welcome to python

# %%
i = 1
while(i<=5):
    print(i, end="")
    i+=1
# Out:
# 12345

# %%
i = 1
while(i<=5):
    print(i, end="")
    i+=1
print("Done")
print("Okay")
# Out:
# 12345Done
# Okay

# %%
i = 1
while(i<=5):
    print(i, end="")
    i+=1
print("")
print("Okay")
# Out:
# 12345
# Okay

# %%
# 12345
# 1234
# 123
# 12
# 1


i = 5
while(i >= 1):
    j = 1
    while(j <= i):
        print(j, end="")
        j+=1
    print()
    i-=1
# Out:
# 12345
# 1234
# 123
# 12
# 1

# %%
#     1
#    21
#   321
#  4321
# 54321

i = 1
while(i <= 5):
    z = 5 - i
    while(z > 0):
        print(" ", end="")
        z -= 1
    
    j = i
    while(j >= 1):
        print(j, end="")
        j -= 1
    print()
    i += 1
# Out:
#     1
#    21
#   321
#  4321
# 54321
