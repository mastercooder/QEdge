# %%
# Arathmatic Operators

a = 3
b = 5

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
print(a ** b)
# Out:
# 8
# -2
# 15
# 0.6
# 0
# 3
# 243

# %%
# Relational Oprators

c = 5
d = 3

if c == d: print("Equal")
if c != d: print("They are not equal")
if c >= d: print(a)
if c <= d: print(b)
if c > d: print(a)
if c < d: print(b)
# Out:
# 5
# 5
# They are not equal

# %%
# Logical Operators

e = 3
f = 8

if(e != f and f != e):
    print("They are not Equal")

if(e != f or f != e):
    print("They are not Equal")

if(not(e > f)):
    print("E is bigger")
# Out:
# They are not Equal
# They are not Equal
# E is bigger
