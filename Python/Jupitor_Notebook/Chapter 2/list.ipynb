# %%
# What is List?
# * List is a build in class to store more then one value
# * It can store any data type values 
# * IT maintains duplicates also
# * List will have positive / negative indexs
# *

# %%
L1 = [10,20,30,40,5]
L2 = [10.45,10.65,10.78,10.43]
L3 = ['python','react','java' ,'javascript' ]
L4 = [1001,'ravi','react',12000,10.45]
L5 = [100,10.45,'welcome', True,None]

# %%
print(L1)
print(L2)
print(L3)
print(L4)
print(L5)

# %%
# Type of anything if we get something then anything is created from something
type(L1)

# %%
# Type of anything if you get type that anything is class
type(list)

# %%
# Indexing and Slicing

# %%
L1 = [10, 20, 30, 40, 50, 60, 70, 80, 90]
print(L1)

# %%
L1[4]

# %%
L1[-4]

# %%
print(L1[:5])

# %%
print(L1[:5])

# %%
print(L1[5:1:2])

# %%
# Reading List with For Loop
# for <var> in <iterableObject>:
#   Statement

# %%
L1 = [100, 200, 300, 400, 500]

# %%
for i in L1:
    print(i)

# %%
L1 = [100, 200, 300, 400, 500]
i = 0
while(i < len(L1)):
    print(L1[i])
    i += 1
# Out:
# 100
# 200
# 300
# 400
# 500

# %%
dir(L1)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
D4 = {hash(1)}

# %%
D1 = {}
type(D1)
# Out:
# dict

# %%
type(dict)
# Out:
# type

# %%
d1 = dict()

# %%
d1
# Out:
# {}

# %%
fruits = {'a':'apple','b':'banana','c':'cherry','d':'dragonfruit'}
fruits
# Out:
# {'a': 'apple', 'b': 'banana', 'c': 'cherry', 'd': 'dragonfruit'}

# %%
fruits['a']
# Out:
# 'apple'

# %%
# Chanding Value with the help of key
# If key is existed if update value
# IF key is not existed it will add new key and value

# %%
D1 = {1: 100, 2:200, 3:300}
D1[1] = 130
D1
# Out:
# {1: 130, 2: 200, 3: 300}

# %%
D1[4] = 400
D1
# Out:
# {1: 130, 2: 200, 3: 300, 4: 400}

# %%
# Reading Dictionary with for loop
fruits
# Out:
# {'a': 'apple', 'b': 'banana', 'c': 'cherry', 'd': 'dragonfruit'}

# %%
for i in fruits:
    print(i, end=" ")
# Out:
# a b c d

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']
