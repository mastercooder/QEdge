# %% [markdown]
# <h1><b><u>JSON File</u></b></h1>
#
# <h2><b><u>1. Working with JSON Files</u></b></h2>
# <i>
# <ol>
# <li>json --> javascript object notation
# <li>It is python module that means json.py file contain function and classes
# <li>It is used to convert json data to python native object as well as python native object(dictinoary) to json
# <li>Json module as method to do it
# <ol>
#     <li>dumps -> python object to json
#     <li>dump --> python object to json file
#     <li>Loads --> json to python object
#     <li>Load --> json file to python object
# </ol>
# </ol>
#
#
#
#
#
#
#
#
#
# </i>

# %%
import json

# %%
student = {
    'first_name': 'Tejesh', 
    'last_name': 'Patel', 
    'course': 'python', 
    'fee': 12500
}

# %%
type(D1)
# Out:
# dict

# %%
D1['first_name']
# Out:
# 'Tejesh'
