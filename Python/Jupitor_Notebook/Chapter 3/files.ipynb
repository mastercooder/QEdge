# %% [markdown]
# # Working with Files

# %% [markdown]
# 1. "open" is function is used to read a file from machine
# 2. open(filepath, mode)

# %% [markdown]
# 1. Open (filepath, mode)
# 2. open funtion will create file object that contains file data from which we can read, write or append operations can be conducted

# %%
type(open)
# Out:
# function

# %%
# reading a file from file data1.txt
fobj1 = open("txt files/data1.txt")

# Same location files
fobj1.read()
# Out:
# 'Welcome to python coding\npython is very good for AI applications \ndjango\njava \nreact \nnextjs\n'

# %%
fobj2 = open("txt files/data1.txt")

# %%
fobj2 = open("txt files/data1.txt")

# %%
# fileobject status related methods

# %%
fileName = r"txt files/data1.txt"

fobj = open(fileName, 'r')

# %%
print(fobj.name)
print(fobj.mode)
print(fobj.fileno())
print(fobj.readable())
print(fobj.writable())
print(fobj.seekable())
print(fobj.close()) # None ---> means files object successfully closed
print(fobj.closed)
# Out:
# txt files/data1.txt
# r
# 6
# True
# False
# True
# None
# True

# %%
# Where 7 is number of character is read 0 to 7 positions 

fileName = "txt files/data1.txt"

fobj1 = open(fileName)

fobj1.read(7)
# Out:
# 'Welcome'

# %%
# It will give you current position of cursor/control

fobj1.tell()
# Out:
# 7

# %%
fobj1.read(4)
# Out:
# ' to '

# %%
fobj1.tell()
# Out:
# 11

# %%
fobj1.read(6)
# Out:
# 'python'

# %%
fobj1.close()

# %%
fobj1 = open('txt files/data1.txt', 'r')

# %%
fobj1.read()
# Out:
# 'Welcome to python coding\npython is very good for AI applications \ndjango\njava \nreact \nnextjs\n'

# %%
fobj1.read()
# Out:
# ''

# %%
fobj1.tell()
# Out:
# 99

# %%
fobj1.seek(0)
# Out:
# 0

# %%
fobj1.tell()
# Out:
# 0

# %%
print(fobj1.read())
# Out:
# Welcome to python coding
# python is very good for AI applications
# django
# java
# react
# nextjs

# %%
fobj1.tell()
# Out:
# 99

# %% [markdown]
# ## ReadLine

# %%
fobj1 = open("txt files/data1.txt", "r")

# %%
fobj1.readline()
# Out:
# 'Welcome to python coding\n'

# %%
fobj1.readline()
# Out:
# 'python is very good for AI applications \n'

# %%
fobj1.readline()
# Out:
# 'django\n'

# %%
fobj1.close()

# %%
fobj1 = open('txt files/data1.txt')

# %%
fobj1.readline()
# Out:
# 'Welcome to python coding\n'

# %%
fobj1.readline(10)
# Out:
# 'python is '

# %%
fobj1.readline(9)
# Out:
# 'very good'

# %%
fobj1.readline()
# Out:
# 'react \n'

# %%
fobj1.readline(45)
# Out:
# 'nextjs\n'

# %%
fobj1 = open('txt files/data1.txt')

# %%
fobj1.readlines()
# Out:
# ['Welcome to python coding\n',
#  'python is very good for AI applications \n',
#  'java script\n',
#  'django\n',
#  'java \n',
#  'react \n',
#  'nextjs\n']

# %%
fobj1.close()

# %%
fobj1 = open("txt files/data2.txt")

# %%
# Output of the readlines in list
fobj1.readlines()
# Out:
# ['html\n',
#  'css\n',
#  'javascript\n',
#  'react\n',
#  'router\n',
#  'python\n',
#  'django\n',
#  'next\n',
#  'fastapi\n',
#  'mongodb\n']

# %%
fobj1 = open("txt files/data2.txt")
courses = fobj1.readlines()

# %%
courses[:]
# Out:
# ['html\n',
#  'css\n',
#  'javascript\n',
#  'react\n',
#  'router\n',
#  'python\n',
#  'django\n',
#  'next\n',
#  'fastapi\n',
#  'mongodb\n']

# %% [markdown]
# ## Read File From Starting

# %%
courses[:3]
# Out:
# ['html\n', 'css\n', 'javascript\n']

# %%
courses[-1:-4:-1]
# Out:
# ['mongodb\n', 'fastapi\n', 'next\n']

# %%
courses[-3::1]
# Out:
# ['next\n', 'fastapi\n', 'mongodb\n']

# %%
courses[0]
# Out:
# 'html\n'

# %% [markdown]
# ## Read File from End

# %%
courses[0][-5:-1:1]
# Out:
# 'html'

# %%
courses[0][:-1]
# Out:
# 'html'

# %%
for i in courses:
    print(i, end="")
# Out:
# html
# css
# javascript
# react
# router
# python
# django
# next
# fastapi
# mongodb

# %%
fobj1 = open('txt files/data2.txt')

# %%
for i in fobj1:
    print(i, end="")
# Out:
# html
# css
# javascript
# react
# router
# python
# django
# next
# fastapi
# mongodb

# %%
for i in fobj1:
    print(i, end="")

# %%
fobj = open('txt files/students.txt')

# %%
for i in fobj:
    print(i, end="")
# Out:
# 1001,tejesh,python,3500
# 1002,patel,java,4000
# 1003,hari,react,3500
# 1004,varma,python,4500
# 1005,koti,Python,3600
# 1006,venkat,JAVA,4700
# 1007,preetham,django,5300
# 1008,singh,PYTHON,4600

# %% [markdown]
# ### Display all Students joined for given course

# %%
"python" in "1001,tejesh,python,3500"
# Out:
# True

# %%
i = "1001,tejesh,python,3500"
course = "python"

# %%
course in i
# Out:
# True

# %%
fobj = open('txt files/students.txt')
course = input("Enter Course Name: ")

for i in fobj:
    if course in i:
        print(i, end="")
# Out:
# 1001,tejesh,python,3500
# 1004,varma,python,4500

# %%
import re

# %%
fobj = open('txt files/students.txt')
course = input("Enter Course Name: ")

for i in fobj:
    if re.search(course, i, re.I):
        print(i, end="")
# Out:
# 1001,tejesh,python,3500
# 1004,varma,python,4500
# 1005,koti,Python,3600
# 1008,singh,PYTHON,4600

# %% [markdown]
# ### Total number of students for given course

# %%
fobj = open('txt files/students.txt')
course = input("Enter Course Name: ")
count = 0
for i in fobj:
    if re.search(course, i, re.I):
        count+=1
else:
    print("Total students joined for {} course is {}".format(course.upper(), count))
# Out:
# Total students joined for PYTHON course is 4

# %% [markdown]
# ### Total revenue for given course

# %%
"1001,tejesh,python,3500".split(",")
# Out:
# ['1001', 'tejesh', 'python', '3500']

# %%
"1001,tejesh,python,3500".split(",")[3]
# Out:
# '3500'

# %%
fobj = open('txt files/students.txt')
course = input("Enter Course Name: ")
rev = 0
for i in fobj:
    if re.search(course, i, re.I):
        rev = rev + int(i.split(",")[3])
else:
    if rev==0:
        print("No such course is Existed")
    else:
        print("Total Revenue for {} course is {}".format(course.upper(), rev))
# Out:
# Total Revenue for J course is 17500

# %%
fobj = open('txt files/students.txt')

for i in fobj:
    print(i, end="")
# Out:
# 1001,tejesh,python,3500
# 1002,patel,java,4000
# 1003,hari,react,3500
# 1004,varma,python,4500
# 1005,koti,Python,3600
# 1006,venkat,JAVA,4700
# 1007,preetham,django,5300
# 1008,singh,PYTHON,4600

# %%
'1001,tejesh,python,3500'.split(",")
# Out:
# ['1001', 'tejesh', 'python', '3500']

# %%
'java scripts'.replace(" ", "")
# Out:
# 'javascripts'

# %%
import re

fobj = open('txt files/students.txt')
course = input("Enter Course Name: ")
rev = 0
for i in fobj:
    if re.fullmatch(re.escape(course), i.split(",")[2].replace(" ", ""), re.I):
        print(i, end="")

# %% [markdown]
# ## Assignment

# %% [markdown]
# 1. Write a Function
#     1. Ask Username and course
#     2. If Course is existed in course then display fee else display no such course is avalable
#     3. Ask Fee to pay for given course
#     4. It has to generate a new Student ID
#     5. Write the data into student.txt file

# %%
import re

courses = {
    'python': 12000,
    'react': 4500,      
    'django': 7000,
    'fastapi': 5500,
    'java': 8000,
    'javascript': 6000
}

fileName = "txt files/students"

sid = input("Enter Sudent ID: ").replace(" ", "")

for i in open('txt files/students.txt'):
    if re.fullmatch(re.escape(sid),i.split(",")[0].replace(" ", "")):
        cname = i.split(",")[2].replace(" ", "").lower()
        std_name = i.split(",")[1].replace(" ", "").capitalize()
        std_fee = int(i.split(",")[3].replace(" ", ""))
        course_fee = courses[cname]
        due_fee = course_fee - std_fee
        
        if due_fee == 0:
            print("{} Your Fees is Clear".format(std_name))
            break
else:
    print("{} Your Due fee is {}".format(std_name, due_fee))
# Out:
# Tejesh Due fee is 8500

# %% [markdown]
# ## Write Method
#
# - Write Method will create new files every time

# %%
fileName = 'txt files/data3.txt'

# %%
fobj = open(fileName, 'w')

# %%
fobj.write("Welcome to Python")
# Out:
# 17

# %%
fobj.close()
