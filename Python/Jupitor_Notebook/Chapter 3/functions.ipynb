# %%
# Functions in Python
# Funtion is named Code
# Funtion is callable named code
# Function is reusable object which is a collable named code

# %%
# Function syntax in python

# 1 way 
def <FunctionName> (parameneters):
    Statement1
    Statement2
    ....
    ...
    return <output>

# %%
# Function Calling
<functionName>(Paramenets)

# %%
# 2nd Way

# %%
def <FunctionName> ():
    return <output>

# %%
<FunctionName> ()

# %%
# we consider output only that which returned by return statement
# function must return output
# function returns output with return statement
# function returns None which doesn't have return statement
# function calling is excuting each and every line inside the body of the function

# %%
def f1():
    print("Welecome to Pyton")

# %%
f1()
# Out:
# Welecome to Pyton

# %%
def f2():
    return 'good morning'

f2()
# Out:
# 'good morning'

# %%
def f3():
    print("Welcome to python")
    return 'Good Morrning'

f3()
# Out:
# Welcome to python
# Good Morrning

# %%
# Assign function execution to varibale
# If you assign function execution/call to variable then it gets ouptut of the funtion

# %%
v1 = f1()
print(v1)
# Out:
# Welecome to Pyton
# None

# %%
v2 = f2()
print(v2)
# Out:
# good morning

# %%
v3 = f3()
# Out:
# Welcome to python

# %%
print(v3)
# Out:
# Good Morrning

# %%
# Understanding Parameter

# %%
def f1(msg):
    return msg

f1('Good Morning')
# Out:
# 'Good Morning'

# %%
# Number of parameteres == number of arguments
f1()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 f1()
#
# TypeError: f1() missing 1 required positional argument: 'msg'

# %%
# Default argument

# %%
def f2(msg="Good Morning"):
    return msg

f2()
# Out:
# 'Good Morning'

# %%
f2('Good Evening')
# Out:
# 'Good Evening'

# %%
f2()
# Out:
# 'Good Morning'

# %%
def add(a, b):
    return a + b

add (10, 20)
# Out:
# 30

# %%
add('Good Morning', ' Tejesh')
# Out:
# 'Good Morning Tejesh'
