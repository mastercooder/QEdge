# %%
# Regular Expression
# IT is used to design pattern 
# We can do any kind of text manipulation
# data analysis 
# search and replace
# data clearning
# datat validation ==> email, contact, country code, data, request,
# text extraction ==> find email, find contacts, find username

# %%
#  Patterns are designed with below one
# =====================================
# meta characterss   --> used to design pattern 
# spefical sequences --> design pattterns 
# metods             --> for searching data

# %%
ans = input("Are you cmming ofr tody calss?")
if ans == 'Yes':
    print("welcome")
else:
    print('Take rest')
# Out:
# Take rest

# %%
# re is a module to implement python regular expressions 
import re

# %%
# match
re.match
# Out:
# <function re.match(pattern, string, flags=0)>

# %%
# what is pattern?
# pattern is that which you called expecting
# string  ---> where you want to check you pattern

# %%
# syntax of match funtion 
re.match(pattern, string)
re.match ---> return 'match object' if it matches pattern in string ===> span, string
re.match ---> return 'None' if it doesn't matches pattern in string ===> None
# Out:
#   Cell In[24], line 4
#     re.match ---> return 'None' if it doesn't matches pattern in string ===> None
#                                            ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
print(re.match("python", "python is good for AI application"))
print(re.match("python", "xpython is good for AI application"))
# Out:
# <re.Match object; span=(0, 6), match='python'>
# None

# %%
print(re.match("python", "python is good for AI application"))
print(re.match("python", "i have joined python fullstack cource"))
print(re.match("PYTHON", "python is good for AI applications"))
print(re.match("PYTHON", "python is good for AI applications", re.I))
print(re.match("PYTHON", "python is good for AI applications", re.IGNORECASE))
# Out:
# <re.Match object; span=(0, 6), match='python'>
# None
# None
# <re.Match object; span=(0, 6), match='python'>
# <re.Match object; span=(0, 6), match='python'>

# %%
str1 = "python is better than java for AI applications"

# %%
# search

# %%
print(re.search("java", str1))
print(re.search('python', str1))
print(re.search('JAVA', str1))
print(re.search('JAVA', str1, re.I))
print(re.search('JAVA', str1, re.IGNORECASE))
# Out:
# <re.Match object; span=(22, 26), match='java'>
# <re.Match object; span=(0, 6), match='python'>
# None
# <re.Match object; span=(22, 26), match='java'>
# <re.Match object; span=(22, 26), match='java'>

# %%
ans = input("Are you coming for today Class?") 
if re.search('yes', ans, re.I):
    print("Welcome")
else:
    print("Take rest")
# Out:
# Welcome

# %%
# meta characters
# disign pattern with meta character
# []  ^ {m, n} + (option1|option2|option3) . ? *

# %%
# [0123456789]  --> it matches at lest one digit 
str1 = input("Enter a string value: ") # 7 a @ 
if re.search('[0-9]', str1):
    print("Matched")
else:
    print("Not Matched")
# Out:
# Not Matched

# %%
# [0-9][0-9]  --> it matches at lest two digit 
str1 = input("Enter a string value: ") # 7 a @ 
if re.search('[0-9][0-9]', str1):
    print("Matched")
else:
    print("Not Matched")

# %%
# ^ caret || Tell program to match the first character
str1 = input("Enter a string value: ") # 7 a @ 
if re.search('^[0-9]', str1):
    print("Matched    ")
else:
    print("Not Matched")
# Out:
# Not Matched

# %%
# $ dollar | Matches the last character
str1 = input("Enter a string value: ") # 7 a @ 
if re.search('[0-9]$', str1):
    print("Matched    ")
else:
    print("Not Matched")
# Out:
# Matched

# %%
# ^ and $ || only one ditit number
str1 = input("Enter a string value: ") # 7 a @ 
if re.search('^[0-9]$', str1):
    print("Matched    ")
else:
    print("Not Matched")
# Out:
# Matched

# %%
# ^ and $ || only two ditit number
str1 = input("Enter a string value: ") # 7 a @ 
if re.search('^[0-9][0-9]$', str1):
    print("Matched    ")
else:
    print("Not Matched")

# %%
# Only 5 digit 

import re

str1 = input("Enter a string value: ") # 7 a @ 
if re.search('^[0-9]{5}$', str1):
    print("Matched    ")
else:
    print("Not Matched")
# Out:
# Matched

# %%
# 3 Digit or more than 3 digit

import re

str1 = input("Enter a string value: ") # 7 a @ 
if re.search('^[0-9]{3,}$', str1):
    print("Matched    ")
else:
    print("Not Matched")
# Out:
# Matched

# %%
# 3 Digit and less then 5

import re

str1 = input("Enter a string value: ") # 7 a @ 
if re.search('^[0-9]{3,5}$', str1):
    print("Matched    ")
else:
    print("Not Matched")

# %%
# only digit take long input

str1 = input("Enter a string value: ") # 7 a @ 
if re.search('^[0-9]+$', str1):
    print("Matched    ")
else:
    print("Not Matched")
# Out:
# Not Matched

# %%
#

str1 = input("Enter a string value: ") # 7 a @ 
if re.search('^(python|java|react|django|node)$', str1):
    print("Matched    ")
else:
    print("Not Matched")
# Out:
# Matched

# %%
# 

str1 = input("Enter a string value: ") # 7 a @ 
if re.search('^[0-9].$', str1):
    print("Matched    ")
else:
    print("Not Matched")
# Out:
# Not Matched

# %%
str1 = input("Enter a string value: ") # 7 a @ 
if re.search('^[0-9]..$', str1):
    print("Matched    ")
else:
    print("Not Matched")
# Out:
# Matched

# %%
# 
str1 = input("Enter a string value: ") # 7 a @ 
if re.search('^python3?$', str1):
    print("Matched    ")
else:
    print("Not Matched")
# Out:
# Matched

# %%
# 
str1 = input("Enter a string value: ") # 7 a @ 
if re.search('^python3*$', str1):
    print("Matched    ")
else:
    print("Not Matched")
# Out:
# Matched

# %%
# Special Seque4nces ==> /d /D /s /S /w /W

# %%
# 
str1 = input("Enter a string value: ") # 7 a @ 
if re.search('^/d$', str1):
    print("Matched    ")
else:
    print("Not Matched")
# Out:
# Not Matched

# %%
if re.search("python.org", "i like python.org website"):
    print("Matched")
else:
    print("Not matched")
# Out:
# Matched

# %%
if re.search(re.escape(input()), 'i like python.org website'):
    print("Matched")
else:
    print("Not Matched")
# Out:
# Matched

# %%
import re
    
pwd1 = input("Enter Password: ")
pwd2 = input("Re-Type Password: ")

if re.search(re.escape(pwd1), pwd2):
    print("Matched")
else:
    print("Not Matched")
# Out:
# Matched

# %%
# re.fullmatch

# %%
# ^pattern$ === fullmatch
    
pwd1 = input("Enter Password: ")
pwd2 = input("Re-Type Password: ")

if re.fullmatch(re.escape(pwd1), pwd2):
    print("Matched")
else:
    print("Not Matched")
# Out:
# Not Matched

# %%
# split

# %%
student = "1001, ravi, python, 14000"

# %%
student
# Out:
# '1001, ravi, python, 14000'

# %%
re.split(",", student)
# Out:
# ['1001', ' ravi', ' python', ' 14000']

# %%
student2 = "1001#ravi#python#14000"

# %%
student2
# Out:
# '1001#ravi#python#14000'

# %%
re.split("#", student2)
# Out:
# ['1001', 'ravi', 'python', '14000']

# %%
student
# Out:
# '1001, ravi, python, 14000'

# %%
re.split('[0-9]', student)
# Out:
# ['', '', '', '', ', ravi, python, ', '', '', '', '', '']

# %%
# Previous day code

# %%
student_emails = [
'raju@zohomail.in',
'kiran@gmail.com',
'akshay@zohomail.in',
'harshit@yahoo.com',
'munna@gmail.com',
'varma@gmail.com',
'kumar@yahoo.com',
'venkat@zohomail.in'
]

print(student_emails)
# Out:
# ['raju@zohomail.in', 'kiran@gmail.com', 'akshay@zohomail.in', 'harshit@yahoo.com', 'munna@gmail.com', 'varma@gmail.com', 'kumar@yahoo.com', 'venkat@zohomail.in']

# %%
customer_contacts = [
'567-456-5823',
'567-436-5823',
'567-446-5823',
'567-456-9823',
'567-456-7823',
'56k-456-2823'
]

for i in customer_contacts:
    print(i)
# Out:
# 567-456-5823
# 567-436-5823
# 567-446-5823
# 567-456-9823
# 567-456-7823
# 56k-456-2823

# %%
import re

for i in customer_contacts:
    contactGrp = re.search("(?P<State>[1-9]{3})-(?P<Exchange>[0-9]{3})-(?P<Phone>[0-9]{4})",i)
    if contactGrp.groupdict()['State' ] == '567':
        print(contactGrp[0])
# Out:
# 567-456-5823
# 567-436-5823
# 567-446-5823
# 567-456-9823
# 567-456-7823
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 5
#       3 for i in customer_contacts:
#       4     contactGrp = re.search("(?P<State>[1-9]{3})-(?P<Exchange>[0-9]{3})-(?P<Phone>[0-9]{4})",i)
# ----> 5     if contactGrp.groupdict()['State' ] == '567':
#       6         print(contactGrp[0])
#
# AttributeError: 'NoneType' object has no attribute 'groupdict'

# %%
str1 = 'complain plain'

# %%
str1.removesuffix("plain")
# Out:
# 'complain '

# %%
str1.removeprefix("complain")
# Out:
# ' plain'

# %%
customer_contacts = [
'5000565823',
'5574365823',
'5374465000',
'5574500023',
'5674567823',
'5574562823',
'5570009823',
'5570009823',
'5570009823'
]
# Out:
# 5000565823
# 5374465000
# 5574500023
# 5570009823
# 5570009823
# 5570009823

# %%
pattern = r"000"

# %%
for i in customer_contacts:
    if re.search(pattern, i):
        print(i)
# Out:
# 5000565823
# 5374465000
# 5574500023
# 5570009823
# 5570009823
# 5570009823

# %%
import re

customer_contacts = [
'5000565823',
'5574365823',
'5374465000',
'5574500023',
'5674567823',
'5574562823',
'5570009823',
'5570009823',
'5570009823'
]

for i in customer_contacts:
    if re.fullmatch('\d{10}', i) and re.search('000', i):
        print(i)
# Out:
# 5000565823
# 5374465000
# 5574500023
# 5570009823
# 5570009823
# 5570009823
