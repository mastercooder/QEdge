# %%
print("Welcome")
# Out:
# Welcome

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("Hello world 2")
# Out:
# Hello world 2

# %%
b = 20

# %%
print(b)
print(id(b))
print(type(b))
# Out:
# 20
# 140731461236232
# <class 'int'>
