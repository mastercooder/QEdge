# %% [markdown]
# <h1><b><u> Map Filter Reduce </u></b></h1>
#
# 1. Map woill create map object which maintains the output of another function
# 2. Zip will read two more iterable objects element parallel

# %%
def square(n):
    return n*n

# %%
square(5)
# Out:
# 25

# %%
square(4)
# Out:
# 16

# %%
L1 = [1, 2, 3, 4, 5]
