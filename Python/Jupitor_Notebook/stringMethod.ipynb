# %%
"WELCOME".lower()
# Out:
# 'welcome'

# %%
for i in 'welcome'.encode('utf-16'):
    print(i, end=" ")
# Out:
# 255 254 119 0 101 0 108 0 99 0 111 0 109 0 101 0

# %%
myself = 'I am learning Web Development'
print(myself.startswith('I'))
print(myself.endswith('t'))
# Out:
# True
# True

# %%
students = ('tejesh', 'tushar', 'Jayesh', 'Bhupesh')

for i in students:
    if("{}".format(i).startswith(students)):
        print("{} attended".format(i))
# Out:
# tejesh attended
# tushar attended
# Jayesh attended
# Bhupesh attended

# %%
course = ('python', 'react', 'javascripts', 'django')


userInput = input("Enter you Course Name: ").lower()
if f"I am looking for {userInput}".endswith(course):
    print("Avalable")
else:
    print("Not Avalable")
# Out:
# Not Avalable

# %%
if "tejesh.patel256@gmail.com".find('@'):
    print("Valid Email")
else:
    print("Invalid Email")
# Out:
# Valid Email

# %%
email = 'tejesh.patel256@gmail.com'

if email.count('@') == 1:
    if email.find('@') >= 4:
        print("Value Email")
    else:
        print("Email must have at least 4 character")
else:
    print("Email must have only 1 @")
# Out:
# Email must have only 1 @

# %%
# Index finds index number of given element
"Welcome".index("e")
# Out:
# 1

# %%
"Welcome to {}".format("Python")
# Out:
# 'Welcome to Python'

# %%
student = {'sid': 1001, 'sname': 'Tejesh', 'Fee': 12500}
"I am {sname} my Id is {sid} i have paid fee {Fee}".format_map(student)
# Out:
# 'I am Tejesh my Id is 1001 i have paid fee 12500'

# %%
"Welcome123".isalnum()
# Out:
# True

# %%
"Welcome123".isalpha()
# Out:
# False

# %%
"Welcome".isascii()
# Out:
# True

# %%
"₹".isascii()
# Out:
# False

# %%
"123".isdecimal()
# Out:
# True

# %%
"123".isdigit()
# Out:
# True

# %%
"Python".join("1234")
# Out:
# '1Python2Python3Python4'

# %%
# ljust ==> Leftside Justification


a = "Welcome".ljust(10)
print(a)
b = "welcome".ljust(7)
print(b)
# Out:
# Welcome
# welcome

# %%
# rjust ==> Right Justification
"welcome".rjust(10)
# Out:
# '   welcome'

# %%
"       Welcome     ".strip()
# Out:
# 'Welcome'

# %%
"***********Welcome*********".strip("*")
# Out:
# 'Welcome'

# %%
"********Wel********co***me***".replace("*", "")
# Out:
# 'Welcome'
