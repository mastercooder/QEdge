# %% [markdown]
# <h1 align='center'><b><u>Django</u></b></h1>
# <hr>
#
# <h2><b><u>Anaconda Commands</u></b></h2>
# <h5><i><b>
# <ol>
#     <li>Create --name env1 python=3.13</li>
#     <li></li>
#     <li></li>
#     <li></li>
# </ol>
# </b></i></h5>
