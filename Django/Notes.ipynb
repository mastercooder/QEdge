# %% [markdown]
# <h1 align='center'><b><u>Django</u></b></h1>
# <hr>
#
# <h2 align='center'><b><u>Important Websites</u></b></h2>
# <h5><i><b>
# <ol>
#     <li>CONDA Docs</li>
#     <li>pypi.org</li>
#     <li>Djangoproject.com</li>
# </ol>
# </b></i></h5><hr>
#
# <h2 align='center'><b><u>Anaconda Commands</u></b></h2>
# <h5><i><b>
# <ol>
#     <li>conda create --name env1 python=3.13</li>
#     <li>conda activate env1</li>
#     <li>pip install django=4.1</li>
#     <li>import django</li>
#     <li>conda activate base</li>
#     <li>conda create --name env2 python==3.13 django==5.0</li>
#     <li>import django</li>
# </ol>
# </b></i></h5><br><hr>
#
#
#
#
# <h2 align='center'><b><u>Python (.venv) Commands</u></b></h2>
#
# <h5><b><i>1. Create a Virtual Environment (.venv)*</i></b></h5>
#
# ```bash
# python -m venv .venv
# ```
#
# <h5><b><i>2. Activate the Virtual Environment</i></b></h5>
#
# **Windows (CMD)**
# ```cmd
# .venv\Scripts\activate
# ```
#
# **Windows (PowerShell)**
# ```powershell
# .venv\Scripts\Activate.ps1
# ```
#
# <h5><b><i>3. Install Django 4.1</i></b></h5>
#
# ```bash
# pip install django==4.1
# ```
#
# <h5><b><i>4. Verify Django Installation</i></b></h5>
#
# ```bash
# python -m django --version
# ```
# <br>
# <h3><b>OR</b></h3>
# <br>
#
# ```python
# import django
# print(django.get_version())
# ```
#
# <h5><b><i>5. Deactivate the Virtual Environment</i></b></h5>
#
# ```bash
# deactivate
# ```
#
# <h5><b><i>6. Create Another Virtual Environment with a Different Python Version</i></b></h5>
# <p><i><b>Note: The required Python version must already be installed.</b></i></p>
#
# ```bash
# py -3.13 -m venv .venv313
# ```
#
# or
#
# ```bash
# py -3.11 -m venv .venv311
# ```
#
# <h5><b><i>7. Activate the New Environment </i></b></h5>
#
# ```cmd
# .venv313\Scripts\activate
# ```
#
# <h5><b><i>8. Install Django 5.0 </i></b></h5>
#
# ```bash
# pip install django==5.0
# ```
#
# <h5><b><i>9. Check Python Version </i></b></h5>
#
# ```bash
# python --version
# ```
#
# <h5><b><i> 10. View Installed Packages</i></b></h5>
# ```bash
# pip list
# ```
#
# <h5><b><i> 11. Freeze Dependencies</i></b></h5>
#
# ```bash
# pip freeze > requirements.txt
# ```
#
# <h5><b><i>12. Install Dependencies from requirements.txt </i></b></h5>
#
# ```bash
# pip install -r requirements.txt
# ```
# <br>
# <hr>

# %% [markdown]
# <h2><b><u>Creating & Starting Django Project</u></b></h2>
#
# <h5><b><i>1. Creating Project</i></b></h5>
#
# ```cmd
# django-admin startproject project_name
# ```
#
# <h5><b><i>2. Start Project</i></b></h5>
#
# ```cmd
# py manage.py runserver
# ```
#
# <h5><b><i>3. Stop Project</i></b></h5>
#
# ```cmd
# Ctrl + C
# ```
# <br><hr>

# %% [markdown]
# <h2><b><u>Steps</u></b></h2>
#
# <h5><b><i>1. Create Enviroment with Python and Django</i></b></h5>
#
# ```bash
# conda create --name env1 python==3.13
# ```
#
# <h5><b><i>2. Activate Environment</i></b></h5>
#
# ```bash
# conda activate env1
# ```
#
# <h5><b><i>3. Go to the location where you want create django project</i></b></h5>
#
# ```cmd
# cd location
# ```
#
# <h5><b><i>4. Create .env</i></b></h5>
#
# ```bash
# python -m venv .env
# ```
#
# <h5><b><i>5. Activate Virtual Environment</i></b></h5>
#
# ```bash
# .env\scripts\activate
# ```
#
# <h5><b><i>6. Install Packages</i></b></h5>
#
# ```bash
# pip install django==5.0
# ```
#
# <h5><b><i>7. Create Project</i></b></h5>
#
# ```bash
# django-admin startproject proj1
# ```
#
# <h5><b><i>8. Go inside project Filies</i></b></h5>
#
# ```cmd
# cd project_name
# ```
#
# <h5><b><i>9. Open Project Inside Vs Code</i></b></h5>
#
# ```cmd
# code .
# ```
#
# <h5><b><i>10. Start Project</i></b></h5>
#
# ```bash
# python manage.py runserver
# ```
#
# <h5><b><i>11. Access Project in Browser</i></b></h5>
#
# ```cmd
# copy url which is generated and paste on browser address bar
# ```
# <br>
# <h3><b><u>File Structure</u></b></h3>
#
# ```text
# proj2/ ------------------------> Root Project Folder
# │
# ├── .env/ ---------------------> Python Virtual Environment (Python 3.11)
# │
# └── mysite/ -------------------> Base Django Directory
#     │
#     ├── manage.py -------------> Start Development Server (Runs project tools)
#     │
#     ├── db.sqlite3 ------------> Database File
#     │
#     └── mysite/ ---------------> Inner Project Configuration Folder
#         ├── __pycache__/
#         ├── __init__.py
#         ├── asgi.py
#         ├── settings.py -------> Main Project Settings
#         ├── urls.py -----------> URL Router / Mappings
#         └── wsgi.py
# ```
# <hr><hr>

# %% [markdown]
# <br>
# <h2 align='center'><b><u>Django Application</u></b></h2><br>
#
# <h3><b><u>Createing Django Application</u></b></h3>
#
# <h5><b><i>1. Go inside Base Django Dictionary</i></b></h5>
#
# ```bash
# cd project_name(mysite)
# ```
#
# <h5><b><i>2. Run Command</i></b></h5>
#
# ```bash
# python manage.py startapp app_name(app1)
#                 or
# django-admin startapp app_name(app1)
#
# ```
# <hr>
#
#
# <h3><b><u>File's Usage</u></b></h3>
# <h5><b><i>
# <li>urls.py  --> This file is used to get and send response || urlpatten</li>
# <li>views.py --> Its a file to make Function</li>
# <li>templates --> .html file usually the fruend-end of the file which is rendered in the user side</li>
# </i></b></h5><hr>

# %% [markdown]
# <h2 align='center'><b><u>Note's</u></b></h2>
#
# <h5><b><i>
# <p>1. What django-admin</p>
# </i></b></h5>
# <b><i>
# <ul>
#     <li>It is a command-line utiltiy in django framework.</li>
#     <li>It is used to create, manage and control django projects and application from terminal </li>
#     <li>Creates new projects</li>
#     <ol>
#         <li>Creates new applications</li>
#         <li>We can run development server</li>
#         <li>apply database migrations</li>
#         <li>it manages the user data</li>
#     </ol>
# </ul>
# </i></b>
#
# <h3><b><u>Commands</u></b></h3>
#
# ```text
#     check
#     compilemessages
#     createcachetable
#     dbshell
#     diffsettings
#     dumpdata
#     flush
#     inspectdb
#     loaddata
#     makemessages
#     makemigrations
#     migrate
#     optimizemigration
#     runserver
#     sendtestemail
#     shell
#     showmigrations
#     sqlflush
#     sqlmigrate
#     sqlsequencereset
#     squashmigrations
#     startapp
#     startproject
#     test
#     testserver
# ```
# <br><hr>

# %% [markdown]
# <h2 align='center'><b><u>Create Admin User</u></b></h2>
#
# <h5><b><i>1. Create Tables</i></b></h5>
#
# ```bash
# python manage.py migrate
# ```
#
# <h5><b><i>2. Create User</i></b></h5>
#
# ```bash
# python manage.py createsuperuser
# ```
#
# <h5><b><i>3. Enter Username, Email & Password</i></b></h5>
#
# ```bash
# username: codeSmith
# email: codesmith@google.in
# password: Welcome@123
# ```
#
# <b><i>Note: White Enterting password it will not be visible for security reason's</i></b>
# <br><br><hr>

# %% [markdown]
# <h2 align='center'><b><u>Bootstrap</u></b></h2>
#
# <h4><b><u><i>We Need 4 Files to Install Bootstrap in our project</i></u></b></h4>
#
#
# ```text
# 1. Compiled CSS and JS: https://getbootstrap.com/docs/5.3/getting-started/download/
#
# 2. Getbootstrap.com: https://getbootstrap.com/docs/5.3/getting-started/introduction/
#     -> https://cdn.jsdelivr.net/npm/@popperjs/core@2.11.8/dist/umd/popper.min.js
#     -> https://cdn.jsdelivr.net/npm/bootstrap@5.3.8/dist/js/bootstrap.min.js
#
# 3. jQuery: https://jquery.com/download/
# ```
# <br><br>
# <i><b>As you can see in the Screenshort The Files are: </b></i>
# <b><i>
# <ul>
#     <li>bootstrap.css</li>
#     <li>bootstrap.js</li>
#     <li>jquery.js</li>
#     <li>popper.js</li>
# </ul>
# </i></b>
#
# ![image.png](attachment:image.png)
